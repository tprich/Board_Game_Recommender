# %% [markdown]
# # User Based Recommender Notebook
# After downloading all of the user rating CSVs from Google Cloud, I will be merging them into one data frame and making sure everthing lines up correctly. Once everything is ready, I will begin making the initial version of the recommender and then improving on it from there.

# %%
import numpy as np
import pandas as pd
from scipy import sparse
from sklearn.metrics.pairwise import pairwise_distances, cosine_distances, cosine_similarity

# %% [markdown]
# ## Generating the User Ratings data frame

# %%
games = pd.read_csv('../data/bg_top1000.csv', index_col='rank')
game_list = list(games['id'])
game_list
# Out:
# [174430,
#  161936,
#  224517,
#  167791,
#  291457,
#  233078,
#  220308,
#  187645,
#  162886,
#  182028,
#  115746,
#  193738,
#  12333,
#  169786,
#  316554,
#  84876,
#  167355,
#  173346,
#  124361,
#  28720,
#  120677,
#  177736,
#  266192,
#  205637,
#  183394,
#  237182,
#  164928,
#  199792,
#  266507,
#  96848,
#  312484,
#  246900,
#  175914,
#  3076,
#  102794,
#  170216,
#  285774,
#  192135,
#  31260,
#  251247,
#  276025,
#  221107,
#  247763,
#  205059,
#  256960,
#  284083,
#  185343,
#  126163,
#  2651,
#  55690,
#  216132,
#  164153,
#  184267,
#  209010,
#  35677,
#  180263,
#  244521,
#  125153,
#  521,
#  161533,
#  230802,
#  72125,
#  25613,
#  266810,
#  191189,
#  124742,
#  342942,
#  28143,
#  314040,
#  201808,
#  159675,
#  121921,
#  229853,
#  171623,
#  157354,
#  68448,
#  200680,
#  110327,
#  62219,
#  182874,
#  236457,
#  264220,
#  122515,
#  93,
#  18602,
#  37111,
#  324856,
#  12493,
#  73439,
#  40834,
#  269385,
#  146021,
#  170042,
#  172386,
#  203993,
#  205896,
#  281259,
#  163412,
#  144733,
#  42,
#  225694,
#  102680,
#  295947,
#  155821,
#  284378,
#  178900,
#  132531,
#  36218,
#  233371,
#  172287,
#  263918,
#  30549,
#  218417,
#  196340,
#  198928,
#  2511,
#  163068,
#  253344,
#  175155,
#  127023,
#  266524,
#  175640,
#  262712,
#  255984,
#  317985,
#  233398,
#  161970,
#  4098,
#  147020,
#  146652,
#  34635,
#  103885,
#  118048,
#  271324,
#  274364,
#  43015,
#  14996,
#  233867,
#  148949,
#  77423,
#  244522,
#  287954,
#  104162,
#  43111,
#  9609,
#  254640,
#  220877,
#  82222,
#  217372,
#  256916,
#  54043,
#  283948,
#  150376,
#  231733,
#  10630,
#  128882,
#  17133,
#  282524,
#  463,
#  155426,
#  296151,
#  308765,
#  39463,
#  221194,
#  70149,
#  103343,
#  265188,
#  188920,
#  199561,
#  279537,
#  25021,
#  14105,
#  123260,
#  31627,
#  195421,
#  283155,
#  171131,
#  189932,
#  104006,
#  21050,
#  126042,
#  182631,
#  245638,
#  223321,
#  91,
#  239188,
#  249259,
#  224037,
#  148228,
#  188,
#  268864,
#  12,
#  146886,
#  215,
#  242302,
#  822,
#  146508,
#  9209,
#  209418,
#  54998,
#  129437,
#  176189,
#  306735,
#  109276,
#  7854,
#  194655,
#  188834,
#  283355,
#  156129,
#  169426,
#  232832,
#  9216,
#  555,
#  318977,
#  192291,
#  158600,
#  155068,
#  199478,
#  271055,
#  198994,
#  31481,
#  20551,
#  176494,
#  293014,
#  118,
#  128621,
#  27833,
#  421,
#  19857,
#  27708,
#  241451,
#  140620,
#  328871,
#  228341,
#  3,
#  127060,
#  269207,
#  204583,
#  235802,
#  155873,
#  108745,
#  92828,
#  24181,
#  295486,
#  271896,
#  144344,
#  274637,
#  97207,
#  286096,
#  760,
#  165722,
#  232405,
#  181279,
#  22545,
#  176734,
#  154203,
#  38453,
#  66589,
#  223040,
#  224783,
#  2655,
#  206718,
#  19777,
#  93260,
#  222509,
#  193037,
#  300531,
#  203420,
#  160477,
#  59294,
#  48726,
#  54138,
#  246784,
#  13122,
#  294484,
#  187617,
#  46213,
#  146439,
#  172081,
#  139976,
#  209685,
#  227224,
#  234,
#  302723,
#  143693,
#  227789,
#  163967,
#  54,
#  140934,
#  40692,
#  136888,
#  172818,
#  45315,
#  260605,
#  101721,
#  129622,
#  77130,
#  257499,
#  181304,
#  5,
#  300322,
#  59959,
#  2653,
#  25292,
#  176920,
#  219513,
#  21241,
#  39856,
#  41114,
#  70919,
#  37046,
#  119890,
#  163745,
#  184921,
#  156546,
#  234487,
#  199042,
#  188866,
#  285967,
#  172,
#  230253,
#  192458,
#  182134,
#  17392,
#  8217,
#  25554,
#  1,
#  50,
#  297030,
#  39683,
#  24480,
#  234277,
#  250458,
#  246192,
#  90137,
#  33160,
#  9217,
#  31594,
#  244271,
#  245934,
#  144592,
#  186751,
#  204305,
#  265736,
#  63888,
#  21348,
#  256226,
#  304420,
#  170771,
#  70323,
#  270633,
#  244711,
#  40765,
#  155987,
#  195539,
#  111341,
#  260428,
#  154809,
#  166669,
#  36932,
#  128271,
#  71,
#  236191,
#  198773,
#  121,
#  54625,
#  243,
#  194594,
#  40354,
#  215311,
#  161614,
#  47,
#  269210,
#  15987,
#  124708,
#  55670,
#  63628,
#  66188,
#  298047,
#  215341,
#  151347,
#  229220,
#  138161,
#  245655,
#  285192,
#  100901,
#  128671,
#  197376,
#  274960,
#  304783,
#  79828,
#  34219,
#  270844,
#  15985,
#  27162,
#  96913,
#  251658,
#  176396,
#  372,
#  66362,
#  92415,
#  11170,
#  192153,
#  18833,
#  105134,
#  311193,
#  262543,
#  137408,
#  314491,
#  150658,
#  25417,
#  62222,
#  150,
#  157969,
#  5404,
#  246684,
#  194607,
#  128996,
#  17226,
#  712,
#  83330,
#  226522,
#  136063,
#  146791,
#  177639,
#  256730,
#  158899,
#  62227,
#  291572,
#  156858,
#  233312,
#  162082,
#  171,
#  478,
#  98778,
#  264241,
#  95527,
#  15062,
#  13,
#  123123,
#  205398,
#  20437,
#  43570,
#  119506,
#  144189,
#  240196,
#  65781,
#  127398,
#  105551,
#  206941,
#  193042,
#  202426,
#  191862,
#  150145,
#  97786,
#  319966,
#  341169,
#  232414,
#  171668,
#  144797,
#  133848,
#  221965,
#  36553,
#  180974,
#  245654,
#  21790,
#  102652,
#  875,
#  125618,
#  269144,
#  12942,
#  142379,
#  147949,
#  9674,
#  31999,
#  262211,
#  58421,
#  11,
#  17405,
#  262215,
#  301880,
#  90419,
#  163968,
#  232043,
#  156009,
#  18,
#  34119,
#  133473,
#  181530,
#  42052,
#  27173,
#  97842,
#  31730,
#  192836,
#  133038,
#  128780,
#  6249,
#  475,
#  218603,
#  91312,
#  183251,
#  151022,
#  256952,
#  22827,
#  277085,
#  316377,
#  141572,
#  27746,
#  196326,
#  84419,
#  15363,
#  3685,
#  153938,
#  252328,
#  183562,
#  2346,
#  329082,
#  159508,
#  297562,
#  155703,
#  39351,
#  298069,
#  140603,
#  39938,
#  212445,
#  160010,
#  170561,
#  169427,
#  28023,
#  6472,
#  175095,
#  172308,
#  9625,
#  503,
#  42215,
#  257501,
#  169255,
#  4390,
#  205359,
#  117959,
#  42776,
#  274638,
#  258210,
#  113924,
#  284435,
#  143519,
#  318084,
#  247367,
#  174785,
#  270673,
#  131357,
#  220,
#  216734,
#  30869,
#  290236,
#  265402,
#  119432,
#  1513,
#  73171,
#  130960,
#  209778,
#  163166,
#  37904,
#  135219,
#  121408,
#  10547,
#  1353,
#  24508,
#  264055,
#  198953,
#  269511,
#  193949,
#  248490,
#  58281,
#  111799,
#  50750,
#  224710,
#  180511,
#  46,
#  121288,
#  3201,
#  21763,
#  5782,
#  150997,
#  303057,
#  13004,
#  203416,
#  116998,
#  70512,
#  107529,
#  216600,
#  134726,
#  266121,
#  30380,
#  245961,
#  296912,
#  113294,
#  699,
#  171499,
#  88,
#  126792,
#  260180,
#  20963,
#  100423,
#  155624,
#  258036,
#  65532,
#  432,
#  173064,
#  160495,
#  123540,
#  213893,
#  318184,
#  170624,
#  163839,
#  181521,
#  162007,
#  154825,
#  146278,
#  153016,
#  239942,
#  3307,
#  168584,
#  72321,
#  29603,
#  190082,
#  15364,
#  9823,
#  143741,
#  193558,
#  165401,
#  87890,
#  2955,
#  232219,
#  156336,
#  242574,
#  242639,
#  73761,
#  167400,
#  244115,
#  2398,
#  226320,
#  214880,
#  69789,
#  31563,
#  7717,
#  68425,
#  256382,
#  22345,
#  233247,
#  132018,
#  283393,
#  270970,
#  55600,
#  179803,
#  586,
#  168435,
#  173442,
#  36235,
#  271518,
#  71721,
#  2163,
#  206480,
#  143515,
#  192457,
#  483,
#  284742,
#  135779,
#  244228,
#  183840,
#  137988,
#  241724,
#  20100,
#  255692,
#  220520,
#  231581,
#  201825,
#  47185,
#  249381,
#  43528,
#  156943,
#  200147,
#  162286,
#  26997,
#  203417,
#  79127,
#  230244,
#  21882,
#  169654,
#  160499,
#  170416,
#  110277,
#  38996,
#  131287,
#  214887,
#  158889,
#  322708,
#  2453,
#  91872,
#  284760,
#  40628,
#  266830,
#  204516,
#  218333,
#  281442,
#  171273,
#  1035,
#  30957,
#  290359,
#  41002,
#  156566,
#  251678,
#  158435,
#  198830,
#  552,
#  306040,
#  117915,
#  280480,
#  12002,
#  191051,
#  24800,
#  179275,
#  244992,
#  181687,
#  163602,
#  202670,
#  177590,
#  197443,
#  256570,
#  28181,
#  12962,
#  51,
#  45,
#  528,
#  252153,
#  148575,
#  18098,
#  194879,
#  299659,
#  161417,
#  145659,
#  166384,
#  12891,
#  113997,
#  103886,
#  244114,
#  217780,
#  283864,
#  35570,
#  11825,
#  137269,
#  12902,
#  94,
#  175117,
#  41,
#  119788,
#  139898,
#  224597,
#  180593,
#  234671,
#  179172,
#  176165,
#  218121,
#  155362,
#  30645,
#  16747,
#  300300,
#  15512,
#  195137,
#  53953,
#  82421,
#  41066,
#  204472,
#  177678,
#  129948,
#  8125,
#  156689,
#  1041,
#  122298,
#  283863,
#  132028,
#  65244,
#  154458,
#  300877,
#  91514,
#  218074,
#  29368,
#  244608,
#  220517,
#  26566,
#  37380,
#  26990,
#  223953,
#  2181,
#  1465,
#  1345,
#  279613,
#  9440,
#  216459,
#  227460,
#  82420,
#  218479,
#  98229,
#  13642,
#  151004,
#  234477,
#  172047,
#  27976,
#  98351,
#  275467,
#  148319,
#  108906,
#  131260,
#  160851,
#  66356,
#  491,
#  239464,
#  65901,
#  195560,
#  240,
#  202408,
#  2093,
#  256999,
#  301255,
#  106217,
#  108784,
#  52461,
#  904,
#  191977,
#  201921,
#  332800,
#  272738,
#  8051,
#  27588,
#  147151,
#  59946,
#  329465,
#  56692,
#  285984,
#  207243,
#  214029,
#  207830,
#  38054,
#  169124,
#  203427,
#  219215,
#  193214,
#  244331,
#  238992,
#  254386,
#  125678,
#  198740,
#  212402,
#  25669,
#  197405,
#  210296,
#  245643,
#  235488,
#  154086,
#  554,
#  248065,
#  171669,
#  95064,
#  280794,
#  174570,
#  19600,
#  242804,
#  69779,
#  273330,
#  177478,
#  158275,
#  196526,
#  66505,
#  180680,
#  939,
#  293296,
#  224,
#  72287,
#  182340,
#  165838,
#  161866,
#  199966,
#  207691,
#  200077,
#  112,
#  168917,
#  178336,
#  15817,
#  131646,
#  299047,
#  228328,
#  298065,
#  72225,
#  204027,
#  264052,
#  150999,
#  157403,
#  66056,
#  276498,
#  230080,
#  195314,
#  256788,
#  200954,
#  267319,
#  227515,
#  104710,
#  75449,
#  156776,
#  85897,
#  1382,
#  185589,
#  253284,
#  104363,
#  218509,
#  164949,
#  157809,
#  141517,
#  163154,
#  160018,
#  127518,
#  228504,
#  284818,
#  89409,
#  229892,
#  8203,
#  22825,
#  198454,
#  177524,
#  171233,
#  217449,
#  1301,
#  284777,
#  244654,
#  1822,
#  130176,
#  40793,
#  270314,
#  6830,
#  136991,
#  60,
#  191231,
#  343905,
#  45986,
#  23540,
#  242684,
#  222514,
#  25568,
#  340466,
#  823,
#  35497,
#  35052,
#  217861,
#  97903,
#  272739,
#  55427,
#  231218,
#  161882,
#  135382,
#  266164,
#  191300,
#  122522,
#  253499,
#  153065,
#  194880,
#  18100,
#  134352,
#  221,
#  159473,
#  91536,
#  270971,
#  197070,
#  21523,
#  239472,
#  1608,
#  551,
#  223750,
#  152162,
#  233262,
#  146312,
#  142326,
#  279254,
#  67492,
#  71671,
#  176371,
#  164265,
#  1634,
#  183571,
#  207336,
#  16992,
#  145639,
#  68264,
#  176544,
#  245487,
#  5737,
#  17329,
#  94246,
#  163642,
#  156091,
#  24068,
#  11971]

# %%
dfs = []
for csv in game_list[:1000]:
    df_game = pd.read_csv('../data/board_game_individual_reviews/'+str(csv)+'_ratings.csv').drop(columns='Unnamed: 0')
    dfs.append(df_game)
all_users = pd.concat(dfs)
all_users.reset_index(drop=True, inplace=True)

# %%
all_users
# Out:
#                     user_id  rating  game_id
# 0               clarkkent22    10.0   174430
# 1                    Garroc    10.0   174430
# 2                  Neva Kee    10.0   174430
# 3              Chris Coyote    10.0   174430
# 4                  Beaushek    10.0   174430
# ...                     ...     ...      ...
# 11170192             realjw     1.0    11971
# 11170193  Watchtowerman1994     1.0    11971
# 11170194          cryptosha     1.0    11971
# 11170195         Noldor1998     1.0    11971
# 11170196              Kenig     1.0    11971
#
# [11170197 rows x 3 columns]

# %%
all_users.isna().sum()
# Out:
# user_id    30
# rating      0
# game_id     0
# dtype: int64

# %%
all_users[all_users['user_id'].isnull()].sort_values('game_id')
# Out:
#          user_id  rating  game_id
# 5167951      NaN     4.0        3
# 8073837      NaN     5.0       11
# 7671573      NaN     6.0       13
# 10004618     NaN     4.0       41
# 9875721      NaN     2.0       45
# 6450364      NaN     4.0       50
# 5738888      NaN     4.0       54
# 9147549      NaN     6.0      432
# 3940159      NaN     4.0      463
# 7500965      NaN     6.0      478
# 4566881      NaN     5.0      822
# 8430640      NaN     2.0     2346
# 9343176      NaN     2.0     2398
# 1528857      NaN     6.0     2651
# 1134967      NaN     7.0     3076
# 8584611      NaN     5.0     4390
# 8945302      NaN     5.0     5782
# 9373931      NaN     5.0     7717
# 10420380     NaN     3.0     8051
# 10823085     NaN     2.0     8203
# 6388446      NaN     6.0     8217
# 4675249      NaN     4.0     9209
# 6539518      NaN     4.0     9217
# 8024923      NaN     4.0     9674
# 9249862      NaN     7.0     9823
# 6869843      NaN     8.0    15987
# 2393544      NaN     4.0    18602
# 7917125      NaN     6.0    21790
# 6399343      NaN     7.0    25554
# 2959528      NaN     5.0    36218

# %%
all_users.shape
# Out:
# (11170197, 3)

# %% [markdown]
# There are only 30 null values, all in user_id. None of the boardgames have multiple nulls, so I checked to see if there 'null', 'na', 'nan', or blank in the actual csv. There is a 'null' listed, meaning it is possible that the person's username is simply 'null', which pandas is reading as a NaN. Since we can't know for sure, and 30 out of 11,170,197 is a drop in the bucket, I am just going to drop the null columns.

# %%
all_users.dropna(inplace=True)

# %%
all_users.shape
# Out:
# (11170167, 3)

# %% [markdown]
# Now that I have the data frame, I am going to convert the usernames to numeric using a dictionary. This is to make the data anonymous and shorten many of the usernames to save on memory.

# %%
user_list = list(all_users['user_id'].unique())
user_list
# Out:
# ['clarkkent22',
#  'Garroc',
#  'Neva Kee',
#  'Chris Coyote',
#  'Beaushek',
#  'ravenpolar',
#  'brenmcgovern',
#  'grovermerc',
#  'Ronnyknox',
#  'webs05',
#  'Iguloy',
#  'Slyght',
#  'Leonce',
#  'rlphay',
#  'testicleez',
#  'crwills',
#  'WeeGee',
#  'Azil3',
#  'KimchiTurtle',
#  'robbin 1',
#  'mcscowl',
#  'kittenhoarder',
#  'Kitarja',
#  'Shampoo4you',
#  'Blood Demon',
#  'stevelabny',
#  'vardamir',
#  'Zottelmonster',
#  'EdmundBlackadder',
#  'gimmster',
#  'Clinton',
#  'nancynm',
#  'mergryphon',
#  'darcypennell',
#  'snorman',
#  'Quotho',
#  'Kha Od Dro',
#  'davidcoleman',
#  'valpop',
#  'camidon',
#  'repairmanjack',
#  'Violet_Iris',
#  'tilde72',
#  'bwarner34',
#  'olafpkyou',
#  'thesumo5',
#  'Tarkan',
#  'Electric421',
#  'Husky Seahawk',
#  'j41c',
#  'adjacentbeastman',
#  'geobaldi5',
#  'Firetracker',
#  'Sassycat',
#  'MountainRoot',
#  'dpbernath',
#  'Kyellan',
#  'Suit Sage',
#  'bwt2q',
#  'oskarkapsel',
#  'Morthai',
#  'Akrimas',
#  'Vex85',
#  'blakdeth',
#  'opticode',
#  'ReinhartTR',
#  'bandersnatch1110',
#  'Anemelos',
#  'Ghanaka',
#  'sonofachung',
#  'Murdockus',
#  'sighlance',
#  'Dimaradona',
#  'robert_stringer22888',
#  'Nyhles',
#  'Slumpy',
#  'EtherealPaints',
#  'Terraformer',
#  'greatredwarrior',
#  'Dathras',
#  'Bajahobo',
#  'Drigan',
#  'Chubby',
#  'valpocarnie',
#  'glick9',
#  'kirby_j3',
#  'RamMegiddo',
#  'Wickershamb',
#  'Ardghal',
#  'gabrie',
#  'barti18',
#  'kzinti',
#  'lukwych',
#  'redpatyk',
#  'aubaine',
#  'squash',
#  'amlitt4',
#  'thebaker1983',
#  'FoxWithTwoTales',
#  'LongTom',
#  'Ninjashadowwarrior',
#  'Veracruza',
#  'CiviliTalismaniac',
#  'axfred',
#  'Paul210',
#  'adilibe',
#  'Eclipse11',
#  'lorinsilver',
#  'gregburbidge',
#  'lodiposh',
#  'suaimondi',
#  'Trevize000',
#  'RedJak7',
#  'Buckets',
#  'hish',
#  'Knecht Ruprecht',
#  'Cybarite',
#  'jond',
#  'yohz',
#  'Enas',
#  'DjScribbles',
#  'ji_fearou',
#  'DAGOBAER',
#  'Nestyr',
#  'HyperionHuxley',
#  'Teamjimby',
#  'Barghy',
#  'calbond',
#  'Necroblaster3000',
#  'tarod83',
#  'KerPow',
#  'GreaserMedic',
#  'Nostrilius',
#  'oxfordslacker',
#  'ovvovv',
#  'YouInventedMe',
#  'Hokay9',
#  'mfaulk80',
#  'bankrupt',
#  'ObsoleteThree',
#  'Zeon',
#  'Gethar',
#  'Snardo',
#  'Robert Olesen',
#  'Alan How',
#  'mustangraider',
#  'coblackmagus',
#  'yurameshi',
#  'Demo12',
#  'LieInKing',
#  'WarlikeHerkimer',
#  'Shadow17',
#  'kantti',
#  'FancyWolverine',
#  'rohin',
#  'MuseLament',
#  'Radioactive Man',
#  'Steeveleo',
#  'Thesonofben',
#  'SharkBait',
#  'cromemox',
#  'Thagor',
#  'Dingbat Meeplepusher',
#  'Drsadico2000',
#  'Riszen',
#  'jamjams32',
#  'VaultBoy',
#  'Kikizosan',
#  'tal342',
#  'ctkinc',
#  'hausboot82',
#  'Tjoeller',
#  'valbharion',
#  'Masterblocker',
#  'Asteroid',
#  'floppi',
#  'feeleye',
#  'dhaeman',
#  'revfds',
#  'TootyBonture',
#  '40thann',
#  'Davido1',
#  'guamikao',
#  'AndySzy',
#  'andytaylor',
#  'PureMagicka',
#  'roboman',
#  'Zuxi',
#  'legius',
#  'wnverhoef',
#  'silentxsound',
#  'HitmanN',
#  'kokokoko3',
#  'esasafe',
#  'Lady Mondegreen',
#  'IluvatarIrmo',
#  'DryHumourist',
#  'Tobi',
#  'Xorron',
#  'Draxx',
#  'davachido',
#  'Actuarially',
#  'SechulLath',
#  'anddav',
#  'RCade_RS',
#  'Apocalypse Dude',
#  'Mukuu',
#  'baseman422',
#  'MrFlibble2999',
#  'sac48738',
#  'Cowfields',
#  'vacekrae',
#  'salisbury58',
#  'cadrian710',
#  'edparkmike1',
#  'Redheaded Pharmacist',
#  'GameFunk',
#  'Coachace',
#  'Yooohhh',
#  'HPLobster',
#  'Phillygee',
#  'adamgrey',
#  'kblarsen',
#  'W01FVF',
#  'cd8dman',
#  'dappersparq',
#  'Dave Stoner',
#  'sneakingfart',
#  'clarity86',
#  'crispy951',
#  'gapsxever',
#  'redtalontpf',
#  'bradsterbw',
#  'ahunter5',
#  'Leftnut',
#  'leadera',
#  'hylsberg',
#  'porghar',
#  'reynaert',
#  'hanshu',
#  'Lyskryss',
#  'wefelker',
#  'rosco83',
#  'Ivedefected',
#  'Bogey777',
#  'kimajakobsen',
#  'pwtrash',
#  'pzoblisein',
#  'akihiro',
#  'bbol24',
#  'Condompete',
#  'Kingmaker76',
#  'Speshul',
#  'Treefritters',
#  'Ramsey54',
#  'Stoods',
#  'MorgOz',
#  'Hexaphim',
#  'Rick Razm',
#  'giorgoskaravidas',
#  'Deverash',
#  'rnickster86',
#  'itsgottabeodin',
#  'Rathje',
#  'Kwaine',
#  'Anemone1777',
#  'astos9000',
#  'Ragecage',
#  'ChorltonUK',
#  'engy',
#  'JFurni',
#  'alaifor',
#  'fiatkid55',
#  'emylovejay',
#  'ruofhuan',
#  'Broshevik',
#  'carnaxcce',
#  'kmckimmy06',
#  'ShadowPenguinZ',
#  'kaerkkk',
#  'Scrotos',
#  'Oslot',
#  'Moofed',
#  'da5idt',
#  'Jeremy R',
#  'malakim0',
#  'Zeshin',
#  'orabbi',
#  'MrPretty',
#  'Jools83',
#  'devaed',
#  'Kheinom',
#  'PGusia',
#  'DaveyB',
#  'TheWalkingChaos',
#  'mufasa_92',
#  'Gothnak',
#  'Dombrovo',
#  'boof3001',
#  'bigmop',
#  'gpalmer87',
#  'gcroy5',
#  'fbi_boy',
#  'Vargeth87',
#  'Heezy',
#  'g1ul10',
#  'AbsZero',
#  'f1tzycent',
#  'Valadorn',
#  'icemanbsb',
#  'kn0r',
#  'Sonath',
#  'RuneHammer',
#  'bafbegagglestic',
#  'bcool680',
#  'GoBluePrice',
#  'beholderalv',
#  'wejejeei',
#  'tkeep13',
#  'ChiefPEZhead',
#  'Archonium',
#  'sennaho',
#  'kartmaze',
#  'NeuroNiky',
#  'aitor9',
#  'StarKid',
#  'RallyBat',
#  'kahran78',
#  'mlaust10',
#  'Adrian_vN',
#  'killblue2',
#  'PhilBrillant',
#  'mrakomor',
#  'aegisx',
#  'Weicardo',
#  'solidd',
#  'jdscorch',
#  'Trollkiing',
#  'kalaheo',
#  'mhristova',
#  'Madfiddler',
#  'fbarrera',
#  'CyprienSaint',
#  'kolarius',
#  'Gerdeez',
#  'Nickel Eye',
#  'jiayaik',
#  'gatts73',
#  'marhew',
#  'bcyeager',
#  'Wildman0326',
#  'ellarionkjeldoran',
#  'Toolman',
#  'lostrikis',
#  'Ravix',
#  'lucifer_667',
#  'Zetasaurus',
#  'sbagnall',
#  'Kovaks',
#  'pettigrosso',
#  'sponkey21',
#  'balawen1',
#  'jbradt2020',
#  'bobweekend',
#  'ArsilHindquarters',
#  'gleepglop1',
#  'Tselin3369',
#  'FSTiletto',
#  'Vaaa',
#  'Rik V',
#  'mundanesoul',
#  'Redward',
#  'kwong512',
#  'EndroGamer',
#  'Dacovan',
#  'mamapapillon',
#  'IAmBatman',
#  'Thargor81',
#  'papagamer72',
#  'TyrelUK',
#  'Jhulio',
#  'Mad_albin',
#  'dbailey',
#  'kenho85',
#  'ZorQc',
#  'JimWolf',
#  'jameel',
#  'Crstphr2',
#  'Seroc',
#  'Entropolus',
#  '3Squared',
#  'SilentBob85',
#  'mcpranno',
#  'Hypnotechnic',
#  'Zaki',
#  'Airdrawn78',
#  'COGGaming',
#  'macolton',
#  'Cellardore',
#  'JimothyHalpert',
#  'mrtheboss',
#  'yobuddy',
#  'ins3kT',
#  'RobertGamer',
#  'ksiazekrzysztof',
#  'jaredryan14',
#  'jiciro',
#  'Paxe',
#  'FantasyNerd8',
#  'hockittodock',
#  'magoula',
#  'chickenman5',
#  'PaleMoon',
#  'deadz',
#  'Xonim',
#  'Pelly54',
#  'jclar169',
#  'rallanking',
#  'FullOfTerrors',
#  'havok03',
#  'artadius',
#  'thebillyj',
#  'BlazeHun',
#  'cromusz',
#  'jjacjackson',
#  'Bastet08',
#  'Jmasterflash',
#  'ricexnxrolls',
#  'wolffrostbrew',
#  'raymondhere',
#  'crogstad',
#  'Midian_Tenebrae',
#  'shanduke2',
#  'Threnody',
#  'anomalouskeklol',
#  'garykressner',
#  'chgoman',
#  'danom',
#  'Polono',
#  'l0g0n',
#  'Masu',
#  'robvw',
#  'freeloshlo',
#  'Mongolo',
#  'gamerlaner',
#  'sinutam',
#  'jau9',
#  'icechamber',
#  'Pantalaimon',
#  'andrewkevin',
#  'SneakiestCaesar',
#  'Once',
#  'Ryber',
#  'george_avramov',
#  'zautman',
#  'albosto',
#  'Operadragon',
#  'p4ss3ng3r',
#  'iamrubocop',
#  'Cheezeatinmonky',
#  'Bamabookwyrm',
#  'ackhem',
#  'Shteevie',
#  'theYeas',
#  'synik224',
#  'mkuepfer',
#  '3kindsofsalt',
#  'MikeBCN',
#  'kcrow8516',
#  'darkrenown',
#  'Tolkana',
#  'Coxerino',
#  'SparkValor',
#  'DexGeek',
#  'cemon',
#  'Negreanu1',
#  'archi206',
#  'Hilaryg',
#  'chokedoke',
#  'conschobhar',
#  'Krusten',
#  'Neil Thomson',
#  'PolkadotTex',
#  'akkarian',
#  'theonlymad',
#  'nachimu',
#  'timedelberry',
#  'Posco',
#  'Skeffington',
#  'Herid',
#  'T1aoMurray',
#  'alta_bob',
#  'Andon',
#  'MightyBluebeard',
#  'RossToss',
#  'Kenobiwan',
#  'AlexMoreau',
#  'wzdan',
#  'Black_Howling',
#  'lordfireyes',
#  'Brighten35',
#  'PaulGrogan',
#  'deskjetter',
#  'yrvn',
#  'Boredflak',
#  'ryanespin',
#  'Finite Jester',
#  'nerdlingmum',
#  'Mandara',
#  'gunhed',
#  'IkWolf',
#  'ralos13',
#  'Gamezombiac',
#  'HoLyMeeN',
#  'd3m853',
#  'pharmenza',
#  'BoardGamer2008',
#  'codeinfused',
#  'lastsurvivor00',
#  'BierBauchBrasilianer',
#  'Jaels',
#  'Baconburgerdog',
#  'Garbinho',
#  'Arglor',
#  'Anteros311',
#  'alfons',
#  'DoctorSmoke',
#  'jordanlmeyers',
#  'Bigshowfan',
#  'jjcomics',
#  'UltraAeolus',
#  'purplesneaks',
#  'freekyflow',
#  'Crispy724',
#  'Slick!',
#  'Landers',
#  'kalanqc',
#  'afittinglie',
#  'throttle',
#  'Thoryana',
#  'NerdyTom',
#  'Reamax',
#  'untitledcause',
#  'bvakrayner',
#  'Doomburrito',
#  'shcho16',
#  'von_kalts',
#  'yesbryn',
#  'nickk88',
#  'coffeeslurper',
#  'zxlime',
#  'JustinDJacobson',
#  'Dallasvi',
#  'kelthuzadm',
#  'shepps36',
#  'Dhrendor',
#  'WICKWARE',
#  'dereklee9819',
#  'Elbe1',
#  'skitz319',
#  'ptbbos',
#  'MorriPovic',
#  'Ayiana',
#  'lucusvonlucus',
#  'masterizze',
#  'aewasted',
#  'LegendOfTheMushroom',
#  'Darkening',
#  'jkelso1',
#  'willdutch',
#  'Achrilon',
#  'HarryB00',
#  'Sastopher',
#  'CellarDoor',
#  'hpark1990',
#  'powlo',
#  'matdavid001',
#  'spacecase90',
#  'Drumheller',
#  'emanko78',
#  'empy',
#  'panagiotiskon',
#  'AmnNate',
#  'mab_guit',
#  'chron x',
#  'mrbonanza',
#  'carkara',
#  'Bigbadblue',
#  'ikitikat',
#  'Skipdandy',
#  'Chongito',
#  'DancingManatee',
#  'Eyegleam',
#  'AndrewMbob',
#  'verudar',
#  'dahlillama',
#  'PKTyson',
#  'LiannaMaelie',
#  'cjharrelson',
#  'Orange Fish Flesh',
#  'Alturis',
#  'DayZ113001',
#  'Jotunx',
#  'namyra',
#  'Vhoghul',
#  'Hrolf29',
#  'Beestick',
#  'Normcutts',
#  'Neoshika',
#  'Germs1040',
#  'Kiliz',
#  'Hydedota',
#  'Inthereal',
#  'mavtrick',
#  'Markenninny',
#  'realoriginal',
#  'weretybe',
#  'joshuabaker',
#  'Kausalitet',
#  'BrotherJekel',
#  'bobek6',
#  'yynderjohn',
#  'Dethpoet',
#  'Hygrom',
#  'jdmay024',
#  'SirAlonne',
#  'ipavetta',
#  'cheshire_cat',
#  'mcuetov',
#  'marksunli',
#  'Kane21',
#  'Sunpai',
#  'Bernaar',
#  'redshadow',
#  'Phalse',
#  'bcnevan',
#  'bmcsorley1',
#  'Mgreer87',
#  'GarrickX',
#  'Rodrigo Santander',
#  'poldi',
#  'mcoppel',
#  'janiusus',
#  'dandp3',
#  'Smarty79',
#  'djfranky',
#  'Bakadeuce',
#  'Marzera',
#  'mathiask',
#  'Valashas',
#  'nickriversband',
#  'andwilk9176',
#  'TeamAE2L',
#  'nestledasani',
#  'howthegodschill',
#  'caerell',
#  'fecsmith',
#  'Eutha',
#  'Duxost',
#  'Furton',
#  'Habilis',
#  'mournful',
#  'bqttger',
#  'stormzbowler',
#  'lagingking',
#  'pickman820',
#  'Dalkinn',
#  'espeo196',
#  'qcell',
#  'despoiler79',
#  'Ziilch',
#  'apscott',
#  'aheaume',
#  'IcculusTheWise',
#  'zigzak77',
#  'gecko1919',
#  'Jhonyb',
#  'earlsanchez69',
#  'cmmayo',
#  'DanielMahdavi',
#  'Kerrzo',
#  'Hunara',
#  'lordvoldemort',
#  'trexgorawr',
#  'boardgamequebec',
#  'Flinton',
#  'RevolverOctopus',
#  'GChums',
#  'Steven Universe',
#  'SSGMightyMouse',
#  'elestren',
#  'Greyrocks',
#  'chifanpoe',
#  'Asinthe',
#  'Jhempi13',
#  'jspredator',
#  'divibyzero',
#  'pauligruber',
#  'MrOrruha',
#  'therunningwolves',
#  'drumsfellow',
#  'bujanowicz',
#  'rjudd12',
#  'HmmMatze',
#  'techdudetx',
#  'laserdave24',
#  'pitac',
#  'fehaar',
#  'UndyingRedComet',
#  'oldfamiliarscene',
#  'taah',
#  'Nevofix',
#  'blackrider81',
#  'crogdor',
#  'Rajja29',
#  'Ravendas',
#  'Garaaspakyo',
#  'Hweaver',
#  'steele22374',
#  'toastp13pm4tz',
#  'miller1983',
#  'HairyPotter',
#  'dustin722',
#  'Mr_Cashwell',
#  'Heathojo',
#  'TalonTamer',
#  'Lhianee',
#  'Humlan',
#  'Conein',
#  'blackonion',
#  'muneco',
#  'KMontanari',
#  'Dragonineden',
#  'ggrunska',
#  'Paragus',
#  'Doxotron',
#  'Tythyrn',
#  'fakeai',
#  'Soulburn',
#  'KietKatDynasty',
#  'yutianwawa',
#  'Opticus',
#  'wells101',
#  'AlanM',
#  'Zhanama',
#  'mtharp61',
#  'Andilian',
#  'noahshu',
#  'Kybar',
#  'jahorner',
#  'aflorin',
#  'jesusramos',
#  'dragonkeeper219',
#  'Ricktor_Black',
#  'fridek',
#  'Doesho',
#  'ReDCell5',
#  'popncoffee',
#  'Batisha',
#  'shadomast',
#  'chrisdoody',
#  'kentonwhite',
#  'Snoochies',
#  'kerklarzarus',
#  'psmaylott',
#  'bard',
#  'unbornchikken',
#  'bforma',
#  'Kurisu2fil',
#  'GrisuderSpielteufel',
#  'bibious',
#  'Eeve',
#  'dbgomes',
#  'GhostWolf69',
#  'GeniusLoci',
#  'kiwtig3',
#  'Conundrum80',
#  'stockysnail',
#  'Davidalurie',
#  'Bulkoth',
#  'zolle001',
#  'hoffmanmw',
#  'swhit321',
#  'zippystar',
#  'ThYr0N',
#  'Supafnk',
#  'Koverath',
#  'yunaforever009',
#  'volkan',
#  'IkariOri',
#  'michael.perkins',
#  'Impermanent',
#  'nazghost',
#  'Icarus599',
#  'Mysk',
#  'BikerX1985',
#  'ExplodingSnail',
#  'twinim',
#  'ZipDizzle',
#  'Guibs',
#  'kirito_1987',
#  'minigno',
#  'Dhargor55',
#  'rave_rd',
#  'theultimateinferno',
#  'ThisIsMichael',
#  'Octavian',
#  'HarryHotspur',
#  'Herjan',
#  'Gil Winters',
#  'ignorantpenguin',
#  'Akerfeldt',
#  'Noznatation',
#  'GARRETTGRENIER',
#  'wemotag',
#  'andreas1234',
#  'quasistellar',
#  'thorium0232',
#  'a_kuhl',
#  'HaiKulture',
#  'Sushiboy',
#  'Primus0788',
#  'YayYoh',
#  'otfeldodja',
#  'rabiddwarf',
#  'Pickle4192',
#  'Bairnt',
#  'DerkyDerk',
#  'scottishbry',
#  'taeryn',
#  'Broth32',
#  'Peprew',
#  'mellman99',
#  'Raynemaker',
#  'Snydeman',
#  'Kit Strong',
#  'baconmaster',
#  'Jebus10000',
#  'ecouch',
#  'IMCarnochan',
#  'toddauspicious',
#  'Taigoro',
#  'eekamouse',
#  'treegrass',
#  'shuggacheez',
#  'Skyrek',
#  'TheOniwaban',
#  'TimoNator85',
#  'thrtyto',
#  'tmebert',
#  'Maawdawg',
#  'CrushU',
#  'Doc Mage',
#  'HitomiKojiru',
#  'c4dillon',
#  'mibar01',
#  'icantdrawanime',
#  'gotstank',
#  'hannibal2208',
#  'JakobStansfield',
#  'DeputyCF',
#  'T-Mo',
#  'griever667',
#  'KernelCop',
#  'krakrs',
#  'jetropolis',
#  'Samplerr',
#  'JPNerd',
#  'BetaTesterPrime',
#  'Fulminata',
#  'FKen',
#  'Danno77',
#  'hclix81',
#  'ehomer666',
#  'lvicentesanchez',
#  'neonops',
#  'Malaki242',
#  'DJinSD',
#  'Yostage',
#  'Grobian',
#  'sergio2',
#  'TheKidd0',
#  'macenkrace',
#  'Haunter',
#  'elclarkey',
#  'BurtGummer',
#  'Boltana',
#  'alarii',
#  'fr33py',
#  'kioten',
#  'Zolzar',
#  'bozean',
#  'Fnar',
#  'pan_satyros',
#  'Nass',
#  'Meradanis',
#  'nekslp',
#  'MechanteAnemone',
#  'johnmattf',
#  'Kythrid',
#  'SillyCheez',
#  'djboss',
#  'Eykir',
#  'haos17',
#  'Kaelistus',
#  'Jake11Simon',
#  'VoodooChild65',
#  'oldestone',
#  'etheric',
#  'Tsara',
#  'Vviandelle',
#  'Qstrike',
#  'SkunkToe',
#  'Goblen',
#  'thefreak',
#  'Keegod',
#  'vints1',
#  'CactusRose',
#  'Berinor',
#  'Re3nforcer',
#  'red_nose',
#  'bpsyc',
#  'BruceJackson',
#  'RecklessCoding',
#  'Moldy_squirrel',
#  'KnightOfZero',
#  'tharkad',
#  'jeffkahn',
#  'Burnham',
#  'Mcdoogs',
#  'turkishkenshin',
#  'storm2380',
#  'PN6728',
#  'jimmysoul',
#  'randywilburn',
#  'heathenjr',
#  'rocketj61',
#  'Drunk_Gamer',
#  'juanjoroig',
#  'TrickyRicky2121',
#  'malkav11',
#  'bytor153',
#  'tapion91',
#  'Goldenmean',
#  'CassetteDeck',
#  'josefsallen',
#  'ctrl',
#  'Fredi der Elch',
#  'Witchdoc',
#  'odmu',
#  'pridurki',
#  'Justicex75',
#  'ts00012',
#  'howardmil',
#  'Siege Golem',
#  'MrWorley',
#  'jurchenman',
#  'Dynalange129',
#  'rudyriot',
#  'dreyankee',
#  'jaeger86',
#  'jadony',
#  'manoflore',
#  'atlseal',
#  'abernath',
#  'ThanNewell',
#  'sgussin',
#  'ChimneyDumper',
#  'Bierzgal',
#  'SetsunaBun',
#  'Shakespeare73',
#  'efreeman',
#  'Malkier74',
#  'mikehancoski',
#  'DonO',
#  'dkean',
#  'Chewiecide',
#  'tigantango',
#  'kesipyc',
#  'Foxtale',
#  'Karui_Kage',
#  'elendil_1',
#  'lancefriday945',
#  'mordenaus',
#  'Skybrush',
#  'PhilP',
#  'ainverso',
#  'Showda',
#  'Proyoyo',
#  'ebridge',
#  'WhiskeyNeat',
#  'HelpMeImScared',
#  'Captainsaluki',
#  'nvekmauvia',
#  'cenlea',
#  'Larzu57',
#  'brokenbokken',
#  'thaos52002',
#  'morikaine',
#  'madspy1337',
#  ...]

# %%
user_dict = {}
for i in range(len(users_converted)):
    user_dict[users_converted[i]] = i+1
user_dict
# If I need to look up a username, I can flip the keys and values and look it up by number
# Out:
# {'clarkkent22': 1,
#  'Garroc': 2,
#  'Neva Kee': 3,
#  'Chris Coyote': 4,
#  'Beaushek': 5,
#  'ravenpolar': 6,
#  'brenmcgovern': 7,
#  'grovermerc': 8,
#  'Ronnyknox': 9,
#  'webs05': 10,
#  'Iguloy': 11,
#  'Slyght': 12,
#  'Leonce': 13,
#  'rlphay': 14,
#  'testicleez': 15,
#  'crwills': 16,
#  'WeeGee': 17,
#  'Azil3': 18,
#  'KimchiTurtle': 19,
#  'robbin 1': 20,
#  'mcscowl': 21,
#  'kittenhoarder': 22,
#  'Kitarja': 23,
#  'Shampoo4you': 24,
#  'Blood Demon': 25,
#  'stevelabny': 26,
#  'vardamir': 27,
#  'Zottelmonster': 28,
#  'EdmundBlackadder': 29,
#  'gimmster': 30,
#  'Clinton': 31,
#  'nancynm': 32,
#  'mergryphon': 33,
#  'darcypennell': 34,
#  'snorman': 35,
#  'Quotho': 36,
#  'Kha Od Dro': 37,
#  'davidcoleman': 38,
#  'valpop': 39,
#  'camidon': 40,
#  'repairmanjack': 41,
#  'Violet_Iris': 42,
#  'tilde72': 43,
#  'bwarner34': 44,
#  'olafpkyou': 45,
#  'thesumo5': 46,
#  'Tarkan': 47,
#  'Electric421': 48,
#  'Husky Seahawk': 49,
#  'j41c': 50,
#  'adjacentbeastman': 51,
#  'geobaldi5': 52,
#  'Firetracker': 53,
#  'Sassycat': 54,
#  'MountainRoot': 55,
#  'dpbernath': 56,
#  'Kyellan': 57,
#  'Suit Sage': 58,
#  'bwt2q': 59,
#  'oskarkapsel': 60,
#  'Morthai': 61,
#  'Akrimas': 62,
#  'Vex85': 63,
#  'blakdeth': 64,
#  'opticode': 65,
#  'ReinhartTR': 66,
#  'bandersnatch1110': 67,
#  'Anemelos': 68,
#  'Ghanaka': 69,
#  'sonofachung': 70,
#  'Murdockus': 71,
#  'sighlance': 72,
#  'Dimaradona': 73,
#  'robert_stringer22888': 74,
#  'Nyhles': 75,
#  'Slumpy': 76,
#  'EtherealPaints': 77,
#  'Terraformer': 78,
#  'greatredwarrior': 79,
#  'Dathras': 80,
#  'Bajahobo': 81,
#  'Drigan': 82,
#  'Chubby': 83,
#  'valpocarnie': 84,
#  'glick9': 85,
#  'kirby_j3': 86,
#  'RamMegiddo': 87,
#  'Wickershamb': 88,
#  'Ardghal': 89,
#  'gabrie': 90,
#  'barti18': 91,
#  'kzinti': 92,
#  'lukwych': 93,
#  'redpatyk': 94,
#  'aubaine': 95,
#  'squash': 96,
#  'amlitt4': 97,
#  'thebaker1983': 98,
#  'FoxWithTwoTales': 99,
#  'LongTom': 100,
#  'Ninjashadowwarrior': 101,
#  'Veracruza': 102,
#  'CiviliTalismaniac': 103,
#  'axfred': 104,
#  'Paul210': 105,
#  'adilibe': 106,
#  'Eclipse11': 107,
#  'lorinsilver': 108,
#  'gregburbidge': 109,
#  'lodiposh': 110,
#  'suaimondi': 111,
#  'Trevize000': 112,
#  'RedJak7': 113,
#  'Buckets': 114,
#  'hish': 115,
#  'Knecht Ruprecht': 116,
#  'Cybarite': 117,
#  'jond': 118,
#  'yohz': 119,
#  'Enas': 120,
#  'DjScribbles': 121,
#  'ji_fearou': 122,
#  'DAGOBAER': 123,
#  'Nestyr': 124,
#  'HyperionHuxley': 125,
#  'Teamjimby': 126,
#  'Barghy': 127,
#  'calbond': 128,
#  'Necroblaster3000': 129,
#  'tarod83': 130,
#  'KerPow': 131,
#  'GreaserMedic': 132,
#  'Nostrilius': 133,
#  'oxfordslacker': 134,
#  'ovvovv': 135,
#  'YouInventedMe': 136,
#  'Hokay9': 137,
#  'mfaulk80': 138,
#  'bankrupt': 139,
#  'ObsoleteThree': 140,
#  'Zeon': 141,
#  'Gethar': 142,
#  'Snardo': 143,
#  'Robert Olesen': 144,
#  'Alan How': 145,
#  'mustangraider': 146,
#  'coblackmagus': 147,
#  'yurameshi': 148,
#  'Demo12': 149,
#  'LieInKing': 150,
#  'WarlikeHerkimer': 151,
#  'Shadow17': 152,
#  'kantti': 153,
#  'FancyWolverine': 154,
#  'rohin': 155,
#  'MuseLament': 156,
#  'Radioactive Man': 157,
#  'Steeveleo': 158,
#  'Thesonofben': 159,
#  'SharkBait': 160,
#  'cromemox': 161,
#  'Thagor': 162,
#  'Dingbat Meeplepusher': 163,
#  'Drsadico2000': 164,
#  'Riszen': 165,
#  'jamjams32': 166,
#  'VaultBoy': 167,
#  'Kikizosan': 168,
#  'tal342': 169,
#  'ctkinc': 170,
#  'hausboot82': 171,
#  'Tjoeller': 172,
#  'valbharion': 173,
#  'Masterblocker': 174,
#  'Asteroid': 175,
#  'floppi': 176,
#  'feeleye': 177,
#  'dhaeman': 178,
#  'revfds': 179,
#  'TootyBonture': 180,
#  '40thann': 181,
#  'Davido1': 182,
#  'guamikao': 183,
#  'AndySzy': 184,
#  'andytaylor': 185,
#  'PureMagicka': 186,
#  'roboman': 187,
#  'Zuxi': 188,
#  'legius': 189,
#  'wnverhoef': 190,
#  'silentxsound': 191,
#  'HitmanN': 192,
#  'kokokoko3': 193,
#  'esasafe': 194,
#  'Lady Mondegreen': 195,
#  'IluvatarIrmo': 196,
#  'DryHumourist': 197,
#  'Tobi': 198,
#  'Xorron': 199,
#  'Draxx': 200,
#  'davachido': 201,
#  'Actuarially': 202,
#  'SechulLath': 203,
#  'anddav': 204,
#  'RCade_RS': 205,
#  'Apocalypse Dude': 206,
#  'Mukuu': 207,
#  'baseman422': 208,
#  'MrFlibble2999': 209,
#  'sac48738': 210,
#  'Cowfields': 211,
#  'vacekrae': 212,
#  'salisbury58': 213,
#  'cadrian710': 214,
#  'edparkmike1': 215,
#  'Redheaded Pharmacist': 216,
#  'GameFunk': 217,
#  'Coachace': 218,
#  'Yooohhh': 219,
#  'HPLobster': 220,
#  'Phillygee': 221,
#  'adamgrey': 222,
#  'kblarsen': 223,
#  'W01FVF': 224,
#  'cd8dman': 225,
#  'dappersparq': 226,
#  'Dave Stoner': 227,
#  'sneakingfart': 228,
#  'clarity86': 229,
#  'crispy951': 230,
#  'gapsxever': 231,
#  'redtalontpf': 232,
#  'bradsterbw': 233,
#  'ahunter5': 234,
#  'Leftnut': 235,
#  'leadera': 236,
#  'hylsberg': 237,
#  'porghar': 238,
#  'reynaert': 239,
#  'hanshu': 240,
#  'Lyskryss': 241,
#  'wefelker': 242,
#  'rosco83': 243,
#  'Ivedefected': 244,
#  'Bogey777': 245,
#  'kimajakobsen': 246,
#  'pwtrash': 247,
#  'pzoblisein': 248,
#  'akihiro': 249,
#  'bbol24': 250,
#  'Condompete': 251,
#  'Kingmaker76': 252,
#  'Speshul': 253,
#  'Treefritters': 254,
#  'Ramsey54': 255,
#  'Stoods': 256,
#  'MorgOz': 257,
#  'Hexaphim': 258,
#  'Rick Razm': 259,
#  'giorgoskaravidas': 260,
#  'Deverash': 261,
#  'rnickster86': 262,
#  'itsgottabeodin': 263,
#  'Rathje': 264,
#  'Kwaine': 265,
#  'Anemone1777': 266,
#  'astos9000': 267,
#  'Ragecage': 268,
#  'ChorltonUK': 269,
#  'engy': 270,
#  'JFurni': 271,
#  'alaifor': 272,
#  'fiatkid55': 273,
#  'emylovejay': 274,
#  'ruofhuan': 275,
#  'Broshevik': 276,
#  'carnaxcce': 277,
#  'kmckimmy06': 278,
#  'ShadowPenguinZ': 279,
#  'kaerkkk': 280,
#  'Scrotos': 281,
#  'Oslot': 282,
#  'Moofed': 283,
#  'da5idt': 284,
#  'Jeremy R': 285,
#  'malakim0': 286,
#  'Zeshin': 287,
#  'orabbi': 288,
#  'MrPretty': 289,
#  'Jools83': 290,
#  'devaed': 291,
#  'Kheinom': 292,
#  'PGusia': 293,
#  'DaveyB': 294,
#  'TheWalkingChaos': 295,
#  'mufasa_92': 296,
#  'Gothnak': 297,
#  'Dombrovo': 298,
#  'boof3001': 299,
#  'bigmop': 300,
#  'gpalmer87': 301,
#  'gcroy5': 302,
#  'fbi_boy': 303,
#  'Vargeth87': 304,
#  'Heezy': 305,
#  'g1ul10': 306,
#  'AbsZero': 307,
#  'f1tzycent': 308,
#  'Valadorn': 309,
#  'icemanbsb': 310,
#  'kn0r': 311,
#  'Sonath': 312,
#  'RuneHammer': 313,
#  'bafbegagglestic': 314,
#  'bcool680': 315,
#  'GoBluePrice': 316,
#  'beholderalv': 317,
#  'wejejeei': 318,
#  'tkeep13': 319,
#  'ChiefPEZhead': 320,
#  'Archonium': 321,
#  'sennaho': 322,
#  'kartmaze': 323,
#  'NeuroNiky': 324,
#  'aitor9': 325,
#  'StarKid': 326,
#  'RallyBat': 327,
#  'kahran78': 328,
#  'mlaust10': 329,
#  'Adrian_vN': 330,
#  'killblue2': 331,
#  'PhilBrillant': 332,
#  'mrakomor': 333,
#  'aegisx': 334,
#  'Weicardo': 335,
#  'solidd': 336,
#  'jdscorch': 337,
#  'Trollkiing': 338,
#  'kalaheo': 339,
#  'mhristova': 340,
#  'Madfiddler': 341,
#  'fbarrera': 342,
#  'CyprienSaint': 343,
#  'kolarius': 344,
#  'Gerdeez': 345,
#  'Nickel Eye': 346,
#  'jiayaik': 347,
#  'gatts73': 348,
#  'marhew': 349,
#  'bcyeager': 350,
#  'Wildman0326': 351,
#  'ellarionkjeldoran': 352,
#  'Toolman': 353,
#  'lostrikis': 354,
#  'Ravix': 355,
#  'lucifer_667': 356,
#  'Zetasaurus': 357,
#  'sbagnall': 358,
#  'Kovaks': 359,
#  'pettigrosso': 360,
#  'sponkey21': 361,
#  'balawen1': 362,
#  'jbradt2020': 363,
#  'bobweekend': 364,
#  'ArsilHindquarters': 365,
#  'gleepglop1': 366,
#  'Tselin3369': 367,
#  'FSTiletto': 368,
#  'Vaaa': 369,
#  'Rik V': 370,
#  'mundanesoul': 371,
#  'Redward': 372,
#  'kwong512': 373,
#  'EndroGamer': 374,
#  'Dacovan': 375,
#  'mamapapillon': 376,
#  'IAmBatman': 377,
#  'Thargor81': 378,
#  'papagamer72': 379,
#  'TyrelUK': 380,
#  'Jhulio': 381,
#  'Mad_albin': 382,
#  'dbailey': 383,
#  'kenho85': 384,
#  'ZorQc': 385,
#  'JimWolf': 386,
#  'jameel': 387,
#  'Crstphr2': 388,
#  'Seroc': 389,
#  'Entropolus': 390,
#  '3Squared': 391,
#  'SilentBob85': 392,
#  'mcpranno': 393,
#  'Hypnotechnic': 394,
#  'Zaki': 395,
#  'Airdrawn78': 396,
#  'COGGaming': 397,
#  'macolton': 398,
#  'Cellardore': 399,
#  'JimothyHalpert': 400,
#  'mrtheboss': 401,
#  'yobuddy': 402,
#  'ins3kT': 403,
#  'RobertGamer': 404,
#  'ksiazekrzysztof': 405,
#  'jaredryan14': 406,
#  'jiciro': 407,
#  'Paxe': 408,
#  'FantasyNerd8': 409,
#  'hockittodock': 410,
#  'magoula': 411,
#  'chickenman5': 412,
#  'PaleMoon': 413,
#  'deadz': 414,
#  'Xonim': 415,
#  'Pelly54': 416,
#  'jclar169': 417,
#  'rallanking': 418,
#  'FullOfTerrors': 419,
#  'havok03': 420,
#  'artadius': 421,
#  'thebillyj': 422,
#  'BlazeHun': 423,
#  'cromusz': 424,
#  'jjacjackson': 425,
#  'Bastet08': 426,
#  'Jmasterflash': 427,
#  'ricexnxrolls': 428,
#  'wolffrostbrew': 429,
#  'raymondhere': 430,
#  'crogstad': 431,
#  'Midian_Tenebrae': 432,
#  'shanduke2': 433,
#  'Threnody': 434,
#  'anomalouskeklol': 435,
#  'garykressner': 436,
#  'chgoman': 437,
#  'danom': 438,
#  'Polono': 439,
#  'l0g0n': 440,
#  'Masu': 441,
#  'robvw': 442,
#  'freeloshlo': 443,
#  'Mongolo': 444,
#  'gamerlaner': 445,
#  'sinutam': 446,
#  'jau9': 447,
#  'icechamber': 448,
#  'Pantalaimon': 449,
#  'andrewkevin': 450,
#  'SneakiestCaesar': 451,
#  'Once': 452,
#  'Ryber': 453,
#  'george_avramov': 454,
#  'zautman': 455,
#  'albosto': 456,
#  'Operadragon': 457,
#  'p4ss3ng3r': 458,
#  'iamrubocop': 459,
#  'Cheezeatinmonky': 460,
#  'Bamabookwyrm': 461,
#  'ackhem': 462,
#  'Shteevie': 463,
#  'theYeas': 464,
#  'synik224': 465,
#  'mkuepfer': 466,
#  '3kindsofsalt': 467,
#  'MikeBCN': 468,
#  'kcrow8516': 469,
#  'darkrenown': 470,
#  'Tolkana': 471,
#  'Coxerino': 472,
#  'SparkValor': 473,
#  'DexGeek': 474,
#  'cemon': 475,
#  'Negreanu1': 476,
#  'archi206': 477,
#  'Hilaryg': 478,
#  'chokedoke': 479,
#  'conschobhar': 480,
#  'Krusten': 481,
#  'Neil Thomson': 482,
#  'PolkadotTex': 483,
#  'akkarian': 484,
#  'theonlymad': 485,
#  'nachimu': 486,
#  'timedelberry': 487,
#  'Posco': 488,
#  'Skeffington': 489,
#  'Herid': 490,
#  'T1aoMurray': 491,
#  'alta_bob': 492,
#  'Andon': 493,
#  'MightyBluebeard': 494,
#  'RossToss': 495,
#  'Kenobiwan': 496,
#  'AlexMoreau': 497,
#  'wzdan': 498,
#  'Black_Howling': 499,
#  'lordfireyes': 500,
#  'Brighten35': 501,
#  'PaulGrogan': 502,
#  'deskjetter': 503,
#  'yrvn': 504,
#  'Boredflak': 505,
#  'ryanespin': 506,
#  'Finite Jester': 507,
#  'nerdlingmum': 508,
#  'Mandara': 509,
#  'gunhed': 510,
#  'IkWolf': 511,
#  'ralos13': 512,
#  'Gamezombiac': 513,
#  'HoLyMeeN': 514,
#  'd3m853': 515,
#  'pharmenza': 516,
#  'BoardGamer2008': 517,
#  'codeinfused': 518,
#  'lastsurvivor00': 519,
#  'BierBauchBrasilianer': 520,
#  'Jaels': 521,
#  'Baconburgerdog': 522,
#  'Garbinho': 523,
#  'Arglor': 524,
#  'Anteros311': 525,
#  'alfons': 526,
#  'DoctorSmoke': 527,
#  'jordanlmeyers': 528,
#  'Bigshowfan': 529,
#  'jjcomics': 530,
#  'UltraAeolus': 531,
#  'purplesneaks': 532,
#  'freekyflow': 533,
#  'Crispy724': 534,
#  'Slick!': 535,
#  'Landers': 536,
#  'kalanqc': 537,
#  'afittinglie': 538,
#  'throttle': 539,
#  'Thoryana': 540,
#  'NerdyTom': 541,
#  'Reamax': 542,
#  'untitledcause': 543,
#  'bvakrayner': 544,
#  'Doomburrito': 545,
#  'shcho16': 546,
#  'von_kalts': 547,
#  'yesbryn': 548,
#  'nickk88': 549,
#  'coffeeslurper': 550,
#  'zxlime': 551,
#  'JustinDJacobson': 552,
#  'Dallasvi': 553,
#  'kelthuzadm': 554,
#  'shepps36': 555,
#  'Dhrendor': 556,
#  'WICKWARE': 557,
#  'dereklee9819': 558,
#  'Elbe1': 559,
#  'skitz319': 560,
#  'ptbbos': 561,
#  'MorriPovic': 562,
#  'Ayiana': 563,
#  'lucusvonlucus': 564,
#  'masterizze': 565,
#  'aewasted': 566,
#  'LegendOfTheMushroom': 567,
#  'Darkening': 568,
#  'jkelso1': 569,
#  'willdutch': 570,
#  'Achrilon': 571,
#  'HarryB00': 572,
#  'Sastopher': 573,
#  'CellarDoor': 574,
#  'hpark1990': 575,
#  'powlo': 576,
#  'matdavid001': 577,
#  'spacecase90': 578,
#  'Drumheller': 579,
#  'emanko78': 580,
#  'empy': 581,
#  'panagiotiskon': 582,
#  'AmnNate': 583,
#  'mab_guit': 584,
#  'chron x': 585,
#  'mrbonanza': 586,
#  'carkara': 587,
#  'Bigbadblue': 588,
#  'ikitikat': 589,
#  'Skipdandy': 590,
#  'Chongito': 591,
#  'DancingManatee': 592,
#  'Eyegleam': 593,
#  'AndrewMbob': 594,
#  'verudar': 595,
#  'dahlillama': 596,
#  'PKTyson': 597,
#  'LiannaMaelie': 598,
#  'cjharrelson': 599,
#  'Orange Fish Flesh': 600,
#  'Alturis': 601,
#  'DayZ113001': 602,
#  'Jotunx': 603,
#  'namyra': 604,
#  'Vhoghul': 605,
#  'Hrolf29': 606,
#  'Beestick': 607,
#  'Normcutts': 608,
#  'Neoshika': 609,
#  'Germs1040': 610,
#  'Kiliz': 611,
#  'Hydedota': 612,
#  'Inthereal': 613,
#  'mavtrick': 614,
#  'Markenninny': 615,
#  'realoriginal': 616,
#  'weretybe': 617,
#  'joshuabaker': 618,
#  'Kausalitet': 619,
#  'BrotherJekel': 620,
#  'bobek6': 621,
#  'yynderjohn': 622,
#  'Dethpoet': 623,
#  'Hygrom': 624,
#  'jdmay024': 625,
#  'SirAlonne': 626,
#  'ipavetta': 627,
#  'cheshire_cat': 628,
#  'mcuetov': 629,
#  'marksunli': 630,
#  'Kane21': 631,
#  'Sunpai': 632,
#  'Bernaar': 633,
#  'redshadow': 634,
#  'Phalse': 635,
#  'bcnevan': 636,
#  'bmcsorley1': 637,
#  'Mgreer87': 638,
#  'GarrickX': 639,
#  'Rodrigo Santander': 640,
#  'poldi': 641,
#  'mcoppel': 642,
#  'janiusus': 643,
#  'dandp3': 644,
#  'Smarty79': 645,
#  'djfranky': 646,
#  'Bakadeuce': 647,
#  'Marzera': 648,
#  'mathiask': 649,
#  'Valashas': 650,
#  'nickriversband': 651,
#  'andwilk9176': 652,
#  'TeamAE2L': 653,
#  'nestledasani': 654,
#  'howthegodschill': 655,
#  'caerell': 656,
#  'fecsmith': 657,
#  'Eutha': 658,
#  'Duxost': 659,
#  'Furton': 660,
#  'Habilis': 661,
#  'mournful': 662,
#  'bqttger': 663,
#  'stormzbowler': 664,
#  'lagingking': 665,
#  'pickman820': 666,
#  'Dalkinn': 667,
#  'espeo196': 668,
#  'qcell': 669,
#  'despoiler79': 670,
#  'Ziilch': 671,
#  'apscott': 672,
#  'aheaume': 673,
#  'IcculusTheWise': 674,
#  'zigzak77': 675,
#  'gecko1919': 676,
#  'Jhonyb': 677,
#  'earlsanchez69': 678,
#  'cmmayo': 679,
#  'DanielMahdavi': 680,
#  'Kerrzo': 681,
#  'Hunara': 682,
#  'lordvoldemort': 683,
#  'trexgorawr': 684,
#  'boardgamequebec': 685,
#  'Flinton': 686,
#  'RevolverOctopus': 687,
#  'GChums': 688,
#  'Steven Universe': 689,
#  'SSGMightyMouse': 690,
#  'elestren': 691,
#  'Greyrocks': 692,
#  'chifanpoe': 693,
#  'Asinthe': 694,
#  'Jhempi13': 695,
#  'jspredator': 696,
#  'divibyzero': 697,
#  'pauligruber': 698,
#  'MrOrruha': 699,
#  'therunningwolves': 700,
#  'drumsfellow': 701,
#  'bujanowicz': 702,
#  'rjudd12': 703,
#  'HmmMatze': 704,
#  'techdudetx': 705,
#  'laserdave24': 706,
#  'pitac': 707,
#  'fehaar': 708,
#  'UndyingRedComet': 709,
#  'oldfamiliarscene': 710,
#  'taah': 711,
#  'Nevofix': 712,
#  'blackrider81': 713,
#  'crogdor': 714,
#  'Rajja29': 715,
#  'Ravendas': 716,
#  'Garaaspakyo': 717,
#  'Hweaver': 718,
#  'steele22374': 719,
#  'toastp13pm4tz': 720,
#  'miller1983': 721,
#  'HairyPotter': 722,
#  'dustin722': 723,
#  'Mr_Cashwell': 724,
#  'Heathojo': 725,
#  'TalonTamer': 726,
#  'Lhianee': 727,
#  'Humlan': 728,
#  'Conein': 729,
#  'blackonion': 730,
#  'muneco': 731,
#  'KMontanari': 732,
#  'Dragonineden': 733,
#  'ggrunska': 734,
#  'Paragus': 735,
#  'Doxotron': 736,
#  'Tythyrn': 737,
#  'fakeai': 738,
#  'Soulburn': 739,
#  'KietKatDynasty': 740,
#  'yutianwawa': 741,
#  'Opticus': 742,
#  'wells101': 743,
#  'AlanM': 744,
#  'Zhanama': 745,
#  'mtharp61': 746,
#  'Andilian': 747,
#  'noahshu': 748,
#  'Kybar': 749,
#  'jahorner': 750,
#  'aflorin': 751,
#  'jesusramos': 752,
#  'dragonkeeper219': 753,
#  'Ricktor_Black': 754,
#  'fridek': 755,
#  'Doesho': 756,
#  'ReDCell5': 757,
#  'popncoffee': 758,
#  'Batisha': 759,
#  'shadomast': 760,
#  'chrisdoody': 761,
#  'kentonwhite': 762,
#  'Snoochies': 763,
#  'kerklarzarus': 764,
#  'psmaylott': 765,
#  'bard': 766,
#  'unbornchikken': 767,
#  'bforma': 768,
#  'Kurisu2fil': 769,
#  'GrisuderSpielteufel': 770,
#  'bibious': 771,
#  'Eeve': 772,
#  'dbgomes': 773,
#  'GhostWolf69': 774,
#  'GeniusLoci': 775,
#  'kiwtig3': 776,
#  'Conundrum80': 777,
#  'stockysnail': 778,
#  'Davidalurie': 779,
#  'Bulkoth': 780,
#  'zolle001': 781,
#  'hoffmanmw': 782,
#  'swhit321': 783,
#  'zippystar': 784,
#  'ThYr0N': 785,
#  'Supafnk': 786,
#  'Koverath': 787,
#  'yunaforever009': 788,
#  'volkan': 789,
#  'IkariOri': 790,
#  'michael.perkins': 791,
#  'Impermanent': 792,
#  'nazghost': 793,
#  'Icarus599': 794,
#  'Mysk': 795,
#  'BikerX1985': 796,
#  'ExplodingSnail': 797,
#  'twinim': 798,
#  'ZipDizzle': 799,
#  'Guibs': 800,
#  'kirito_1987': 801,
#  'minigno': 802,
#  'Dhargor55': 803,
#  'rave_rd': 804,
#  'theultimateinferno': 805,
#  'ThisIsMichael': 806,
#  'Octavian': 807,
#  'HarryHotspur': 808,
#  'Herjan': 809,
#  'Gil Winters': 810,
#  'ignorantpenguin': 811,
#  'Akerfeldt': 812,
#  'Noznatation': 813,
#  'GARRETTGRENIER': 814,
#  'wemotag': 815,
#  'andreas1234': 816,
#  'quasistellar': 817,
#  'thorium0232': 818,
#  'a_kuhl': 819,
#  'HaiKulture': 820,
#  'Sushiboy': 821,
#  'Primus0788': 822,
#  'YayYoh': 823,
#  'otfeldodja': 824,
#  'rabiddwarf': 825,
#  'Pickle4192': 826,
#  'Bairnt': 827,
#  'DerkyDerk': 828,
#  'scottishbry': 829,
#  'taeryn': 830,
#  'Broth32': 831,
#  'Peprew': 832,
#  'mellman99': 833,
#  'Raynemaker': 834,
#  'Snydeman': 835,
#  'Kit Strong': 836,
#  'baconmaster': 837,
#  'Jebus10000': 838,
#  'ecouch': 839,
#  'IMCarnochan': 840,
#  'toddauspicious': 841,
#  'Taigoro': 842,
#  'eekamouse': 843,
#  'treegrass': 844,
#  'shuggacheez': 845,
#  'Skyrek': 846,
#  'TheOniwaban': 847,
#  'TimoNator85': 848,
#  'thrtyto': 849,
#  'tmebert': 850,
#  'Maawdawg': 851,
#  'CrushU': 852,
#  'Doc Mage': 853,
#  'HitomiKojiru': 854,
#  'c4dillon': 855,
#  'mibar01': 856,
#  'icantdrawanime': 857,
#  'gotstank': 858,
#  'hannibal2208': 859,
#  'JakobStansfield': 860,
#  'DeputyCF': 861,
#  'T-Mo': 862,
#  'griever667': 863,
#  'KernelCop': 864,
#  'krakrs': 865,
#  'jetropolis': 866,
#  'Samplerr': 867,
#  'JPNerd': 868,
#  'BetaTesterPrime': 869,
#  'Fulminata': 870,
#  'FKen': 871,
#  'Danno77': 872,
#  'hclix81': 873,
#  'ehomer666': 874,
#  'lvicentesanchez': 875,
#  'neonops': 876,
#  'Malaki242': 877,
#  'DJinSD': 878,
#  'Yostage': 879,
#  'Grobian': 880,
#  'sergio2': 881,
#  'TheKidd0': 882,
#  'macenkrace': 883,
#  'Haunter': 884,
#  'elclarkey': 885,
#  'BurtGummer': 886,
#  'Boltana': 887,
#  'alarii': 888,
#  'fr33py': 889,
#  'kioten': 890,
#  'Zolzar': 891,
#  'bozean': 892,
#  'Fnar': 893,
#  'pan_satyros': 894,
#  'Nass': 895,
#  'Meradanis': 896,
#  'nekslp': 897,
#  'MechanteAnemone': 898,
#  'johnmattf': 899,
#  'Kythrid': 900,
#  'SillyCheez': 901,
#  'djboss': 902,
#  'Eykir': 903,
#  'haos17': 904,
#  'Kaelistus': 905,
#  'Jake11Simon': 906,
#  'VoodooChild65': 907,
#  'oldestone': 908,
#  'etheric': 909,
#  'Tsara': 910,
#  'Vviandelle': 911,
#  'Qstrike': 912,
#  'SkunkToe': 913,
#  'Goblen': 914,
#  'thefreak': 915,
#  'Keegod': 916,
#  'vints1': 917,
#  'CactusRose': 918,
#  'Berinor': 919,
#  'Re3nforcer': 920,
#  'red_nose': 921,
#  'bpsyc': 922,
#  'BruceJackson': 923,
#  'RecklessCoding': 924,
#  'Moldy_squirrel': 925,
#  'KnightOfZero': 926,
#  'tharkad': 927,
#  'jeffkahn': 928,
#  'Burnham': 929,
#  'Mcdoogs': 930,
#  'turkishkenshin': 931,
#  'storm2380': 932,
#  'PN6728': 933,
#  'jimmysoul': 934,
#  'randywilburn': 935,
#  'heathenjr': 936,
#  'rocketj61': 937,
#  'Drunk_Gamer': 938,
#  'juanjoroig': 939,
#  'TrickyRicky2121': 940,
#  'malkav11': 941,
#  'bytor153': 942,
#  'tapion91': 943,
#  'Goldenmean': 944,
#  'CassetteDeck': 945,
#  'josefsallen': 946,
#  'ctrl': 947,
#  'Fredi der Elch': 948,
#  'Witchdoc': 949,
#  'odmu': 950,
#  'pridurki': 951,
#  'Justicex75': 952,
#  'ts00012': 953,
#  'howardmil': 954,
#  'Siege Golem': 955,
#  'MrWorley': 956,
#  'jurchenman': 957,
#  'Dynalange129': 958,
#  'rudyriot': 959,
#  'dreyankee': 960,
#  'jaeger86': 961,
#  'jadony': 962,
#  'manoflore': 963,
#  'atlseal': 964,
#  'abernath': 965,
#  'ThanNewell': 966,
#  'sgussin': 967,
#  'ChimneyDumper': 968,
#  'Bierzgal': 969,
#  'SetsunaBun': 970,
#  'Shakespeare73': 971,
#  'efreeman': 972,
#  'Malkier74': 973,
#  'mikehancoski': 974,
#  'DonO': 975,
#  'dkean': 976,
#  'Chewiecide': 977,
#  'tigantango': 978,
#  'kesipyc': 979,
#  'Foxtale': 980,
#  'Karui_Kage': 981,
#  'elendil_1': 982,
#  'lancefriday945': 983,
#  'mordenaus': 984,
#  'Skybrush': 985,
#  'PhilP': 986,
#  'ainverso': 987,
#  'Showda': 988,
#  'Proyoyo': 989,
#  'ebridge': 990,
#  'WhiskeyNeat': 991,
#  'HelpMeImScared': 992,
#  'Captainsaluki': 993,
#  'nvekmauvia': 994,
#  'cenlea': 995,
#  'Larzu57': 996,
#  'brokenbokken': 997,
#  'thaos52002': 998,
#  'morikaine': 999,
#  'madspy1337': 1000,
#  ...}

# %%
all_users['user_id'] = all_users['user_id'].map(user_dict)

# %%
all_users
# Out:
#           user_id  rating  game_id
# 0               1    10.0   174430
# 1               2    10.0   174430
# 2               3    10.0   174430
# 3               4    10.0   174430
# 4               5    10.0   174430
# ...           ...     ...      ...
# 11170192   202730     1.0    11971
# 11170193    21095     1.0    11971
# 11170194    45184     1.0    11971
# 11170195    77129     1.0    11971
# 11170196   128901     1.0    11971
#
# [11170167 rows x 3 columns]

# %%
games
# Out:
#                                title      id
# rank
# 1                         Gloomhaven  174430
# 2          Pandemic Legacy: Season 1  161936
# 3                  Brass: Birmingham  224517
# 4                  Terraforming Mars  167791
# 5       Gloomhaven: Jaws of the Lion  291457
# ...                              ...     ...
# 996     1812: The Invasion of Canada   94246
# 997                  Chimera Station  163642
# 998   Sons of Anarchy: Men of Mayhem  156091
# 999                   Shadow Hunters   24068
# 1000                 Cockroach Poker   11971
#
# [1000 rows x 2 columns]

# %%
user_reviews = pd.merge(games, all_users, left_on='id', right_on='game_id').drop(columns='game_id')

# %%
user_reviews
# Out:
#                     title      id  user_id  rating
# 0              Gloomhaven  174430        1    10.0
# 1              Gloomhaven  174430        2    10.0
# 2              Gloomhaven  174430        3    10.0
# 3              Gloomhaven  174430        4    10.0
# 4              Gloomhaven  174430        5    10.0
# ...                   ...     ...      ...     ...
# 11170162  Cockroach Poker   11971   202730     1.0
# 11170163  Cockroach Poker   11971    21095     1.0
# 11170164  Cockroach Poker   11971    45184     1.0
# 11170165  Cockroach Poker   11971    77129     1.0
# 11170166  Cockroach Poker   11971   128901     1.0
#
# [11170167 rows x 4 columns]

# %%
user_reviews.to_csv('../data/all_user_reviews.csv', index=False)

# %% [markdown]
# Confirming the CSV reloads with all of the data

# %%
user_reviews = pd.read_csv('../data/all_user_reviews.csv')

# %%
user_reviews
# Out:
#                     title      id  user_id  rating
# 0              Gloomhaven  174430        1    10.0
# 1              Gloomhaven  174430        2    10.0
# 2              Gloomhaven  174430        3    10.0
# 3              Gloomhaven  174430        4    10.0
# 4              Gloomhaven  174430        5    10.0
# ...                   ...     ...      ...     ...
# 11170162  Cockroach Poker   11971   202730     1.0
# 11170163  Cockroach Poker   11971    21095     1.0
# 11170164  Cockroach Poker   11971    45184     1.0
# 11170165  Cockroach Poker   11971    77129     1.0
# 11170166  Cockroach Poker   11971   128901     1.0
#
# [11170167 rows x 4 columns]

# %% [markdown]
# ## Creating the Sparse Matrix

# %%
pivot = user_reviews.pivot_table(values='rating', index='title', columns='user_id')
pivot.head(3)
# Out:
# user_id                            1       2       3       4       5       \
# title
# 13 Days: The Cuban Missile Crisis     NaN     NaN     NaN     NaN     NaN
# 1775: Rebellion                       NaN     NaN     NaN     NaN     NaN
# 1812: The Invasion of Canada          NaN     NaN     NaN     NaN     NaN
#
# user_id                            6       7       8       9       10      \
# title
# 13 Days: The Cuban Missile Crisis     NaN     NaN     NaN     NaN     8.0
# 1775: Rebellion                       NaN     NaN     NaN     NaN     NaN
# 1812: The Invasion of Canada          NaN     NaN     NaN     NaN     NaN
#
# user_id                            ...  369309  369310  369311  369312  \
# title                              ...
# 13 Days: The Cuban Missile Crisis  ...     NaN     NaN     NaN     NaN
# 1775: Rebellion                    ...     NaN     NaN     NaN     NaN
# 1812: The Invasion of Canada       ...     NaN     NaN     NaN     NaN
#
# user_id                            369313  369314  369315  369316  369317  \
# title
# 13 Days: The Cuban Missile Crisis     NaN     NaN     NaN     NaN     NaN
# 1775: Rebellion                       NaN     NaN     NaN     NaN     NaN
# 1812: The Invasion of Canada          NaN     NaN     NaN     NaN     NaN
#
# user_id                            369318
# title
# 13 Days: The Cuban Missile Crisis     NaN
# 1775: Rebellion                       NaN
# 1812: The Invasion of Canada          NaN
#
# [3 rows x 369318 columns]

# %%
pivot_sparse = sparse.csr_matrix(pivot.fillna(0))

# %%
similarities = cosine_similarity(pivot_sparse)
similarities
# Out:
# array([[1.        , 0.18433832, 0.12715531, ..., 0.04591301, 0.10277826,
#         0.07798308],
#        [0.18433832, 1.        , 0.32914166, ..., 0.03577458, 0.11504694,
#         0.07572326],
#        [0.12715531, 0.32914166, 1.        , ..., 0.02658886, 0.12387175,
#         0.0912043 ],
#        ...,
#        [0.04591301, 0.03577458, 0.02658886, ..., 1.        , 0.06988396,
#         0.03474348],
#        [0.10277826, 0.11504694, 0.12387175, ..., 0.06988396, 1.        ,
#         0.18231853],
#        [0.07798308, 0.07572326, 0.0912043 , ..., 0.03474348, 0.18231853,
#         1.        ]])

# %%
recommender = pd.DataFrame(similarities, index=pivot.index, columns=pivot.index)
recommender.head()
# Out:
# title                              13 Days: The Cuban Missile Crisis  \
# title
# 13 Days: The Cuban Missile Crisis                           1.000000
# 1775: Rebellion                                             0.184338
# 1812: The Invasion of Canada                                0.127155
# 1830: Railways & Robber Barons                              0.100436
# 1846: The Race for the Midwest                              0.122951
#
# title                              1775: Rebellion  \
# title
# 13 Days: The Cuban Missile Crisis         0.184338
# 1775: Rebellion                           1.000000
# 1812: The Invasion of Canada              0.329142
# 1830: Railways & Robber Barons            0.103055
# 1846: The Race for the Midwest            0.112302
#
# title                              1812: The Invasion of Canada  \
# title
# 13 Days: The Cuban Missile Crisis                      0.127155
# 1775: Rebellion                                        0.329142
# 1812: The Invasion of Canada                           1.000000
# 1830: Railways & Robber Barons                         0.102559
# 1846: The Race for the Midwest                         0.088857
#
# title                              1830: Railways & Robber Barons  \
# title
# 13 Days: The Cuban Missile Crisis                        0.100436
# 1775: Rebellion                                          0.103055
# 1812: The Invasion of Canada                             0.102559
# 1830: Railways & Robber Barons                           1.000000
# 1846: The Race for the Midwest                           0.383197
#
# title                              1846: The Race for the Midwest  \
# title
# 13 Days: The Cuban Missile Crisis                        0.122951
# 1775: Rebellion                                          0.112302
# 1812: The Invasion of Canada                             0.088857
# 1830: Railways & Robber Barons                           0.383197
# 1846: The Race for the Midwest                           1.000000
#
# title                              1960: The Making of the President  \
# title
# 13 Days: The Cuban Missile Crisis                           0.193931
# 1775: Rebellion                                             0.183761
# 1812: The Invasion of Canada                                0.166918
# 1830: Railways & Robber Barons                              0.178309
# 1846: The Race for the Midwest                              0.133292
#
# title                              1989: Dawn of Freedom  5-Minute Dungeon  \
# title
# 13 Days: The Cuban Missile Crisis               0.164322          0.054591
# 1775: Rebellion                                 0.148974          0.038763
# 1812: The Invasion of Canada                    0.160656          0.030154
# 1830: Railways & Robber Barons                  0.131280          0.027402
# 1846: The Race for the Midwest                  0.100791          0.028395
#
# title                              51st State: Master Set  6 nimmt!  ...  \
# title                                                                ...
# 13 Days: The Cuban Missile Crisis                0.111366  0.136089  ...
# 1775: Rebellion                                  0.090142  0.104827  ...
# 1812: The Invasion of Canada                     0.052901  0.098127  ...
# 1830: Railways & Robber Barons                   0.056155  0.143993  ...
# 1846: The Race for the Midwest                   0.059622  0.110412  ...
#
# title                               ZhanGuo  Zombicide  \
# title
# 13 Days: The Cuban Missile Crisis  0.117540   0.078694
# 1775: Rebellion                    0.103244   0.091013
# 1812: The Invasion of Canada       0.080917   0.081118
# 1830: Railways & Robber Barons     0.132375   0.063204
# 1846: The Race for the Midwest     0.127282   0.043289
#
# title                              Zombicide Season 2: Prison Outbreak  \
# title
# 13 Days: The Cuban Missile Crisis                             0.042705
# 1775: Rebellion                                               0.047707
# 1812: The Invasion of Canada                                  0.044655
# 1830: Railways & Robber Barons                                0.031650
# 1846: The Race for the Midwest                                0.019702
#
# title                              Zombicide Season 3: Rue Morgue  \
# title
# 13 Days: The Cuban Missile Crisis                        0.033217
# 1775: Rebellion                                          0.034226
# 1812: The Invasion of Canada                             0.029540
# 1830: Railways & Robber Barons                           0.022634
# 1846: The Race for the Midwest                           0.017936
#
# title                              Zombicide: Black Plague  \
# title
# 13 Days: The Cuban Missile Crisis                 0.070582
# 1775: Rebellion                                   0.066430
# 1812: The Invasion of Canada                      0.050581
# 1830: Railways & Robber Barons                    0.041803
# 1846: The Race for the Midwest                    0.037497
#
# title                              Zombicide: Green Horde  Zombicide: Invader  \
# title
# 13 Days: The Cuban Missile Crisis                0.032711            0.025349
# 1775: Rebellion                                  0.029193            0.024627
# 1812: The Invasion of Canada                     0.022436            0.022589
# 1830: Railways & Robber Barons                   0.018255            0.015949
# 1846: The Race for the Midwest                   0.016936            0.013754
#
# title                              Zombie Kidz Evolution  Zooloretto     ZÈRTZ
# title
# 13 Days: The Cuban Missile Crisis               0.045913    0.102778  0.077983
# 1775: Rebellion                                 0.035775    0.115047  0.075723
# 1812: The Invasion of Canada                    0.026589    0.123872  0.091204
# 1830: Railways & Robber Barons                  0.022901    0.132606  0.117823
# 1846: The Race for the Midwest                  0.023662    0.084733  0.083904
#
# [5 rows x 996 columns]
