# %% [markdown]
# # Category Based Recommender
# In this notebook, I will be creating the recommender that only uses categorical data. I will do that using filters based on user inputs to give the best recommendations based on what the user is looking for.

# %%
import numpy as np
import pandas as pd
import pickle

# %%
df = pd.read_csv('../data/game_details.csv')
df.head()
# Out:
#    game_id                     game_name  \
# 0   174430                    Gloomhaven
# 1   161936     Pandemic Legacy: Season 1
# 2   224517             Brass: Birmingham
# 3   167791             Terraforming Mars
# 4   291457  Gloomhaven: Jaws of the Lion
#
#                                             game_des  game_yr_pub  \
# 0  Gloomhaven  is a game of Euro-inspired tactica...         2017
# 1  Pandemic Legacy is a co-operative campaign gam...         2015
# 2  Brass: Birmingham is an economic strategy game...         2018
# 3  In the 2400s, mankind begins to terraform the ...         2016
# 4  Gloomhaven: Jaws of the Lion is a standalone g...         2020
#
#    min_players  max_players  min_play_time  max_play_time  min_age  \
# 0            1            4             60            120       14
# 1            2            4             60             60       13
# 2            2            4             60            120       14
# 3            1            5            120            120       12
# 4            1            4             30            120       14
#
#    num_ratings  ...  bayes_avg_rating  overall_rank_bayesavg  \
# 0        49737  ...           8.49563              1|8.49563
# 1        46207  ...           8.43544              2|8.43544
# 2        27629  ...           8.42263              3|8.42263
# 3        77570  ...           8.26819              5|8.26819
# 4        18796  ...           8.27022              4|8.27022
#
#                             family_rank_bayes complexity  \
# 0  thematic/1/8.47366|strategygames/1/8.46295     3.8728
# 1  thematic/2/8.42624|strategygames/3/8.42193     2.8302
# 2                     strategygames/2/8.45557     3.9043
# 3                     strategygames/6/8.24833     3.2478
# 4  thematic/3/8.30864|strategygames/5/8.27021     3.5908
#
#                                           categories  \
# 0  Adventure|Exploration|Fantasy|Fighting|Miniatures
# 1                              Environmental|Medical
# 2  Economic|Industry / Manufacturing|Post-Napoleo...
# 3  Economic|Environmental|Industry / Manufacturin...
# 4  Adventure|Exploration|Fantasy|Fighting|Miniatures
#
#                                            mechanics  \
# 0  Action Queue|Action Retrieval|Campaign / Battl...
# 1  Action Points|Cooperative Game|Hand Management...
# 2  Hand Management|Income|Loans|Market|Network an...
# 3  Closed Drafting|Contracts|Enclosure|End Game B...
# 4  Action Queue|Action Retrieval|Campaign / Battl...
#
#                                             families  \
# 0  Category: Dungeon Crawler|Components: Miniatur...
# 1  Components: Map (Global Scale)|Components: Mul...
# 2  Cities: Birmingham (England)|Country: England|...
# 3  Components: Map (Global Scale)|Components: Mul...
# 4  Category: Dungeon Crawler|Components: Book as ...
#
#                                      implementations  \
# 0                                                NaN
# 1                 Pandemic Legacy: Season 2|Pandemic
# 2                                  Brass: Lancashire
# 3  Terraforming Mars: Ares Expedition|Terraformin...
# 4                                                NaN
#
#                                 designers  \
# 0                          Isaac Childres
# 1                 Rob Daviau|Matt Leacock
# 2  Gavan Brown|Matt Tolman|Martin Wallace
# 3                         Jacob Fryxelius
# 4                          Isaac Childres
#
#                                           publishers
# 0  Cephalofair Games|Albi|Albi Polska|Arclight|As...
# 1  Z-Man Games|Asterion Press|Devir|Filosofia Édi...
# 2  Roxley|Arclight|BoardM Factory|Conclave Editor...
# 3  FryxGames|Arclight|Brädspel.se|Fantasmagoria|G...
# 4  Cephalofair Games|Albi|Albi Polska|Asmodee|Asm...
#
# [5 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['game_id', 'game_name', 'game_des', 'game_yr_pub', 'min_players',
#        'max_players', 'min_play_time', 'max_play_time', 'min_age',
#        'num_ratings', 'avg_rating', 'bayes_avg_rating',
#        'overall_rank_bayesavg', 'family_rank_bayes', 'complexity',
#        'categories', 'mechanics', 'families', 'implementations', 'designers',
#        'publishers'],
#       dtype='object')

# %%
df.dtypes
# Out:
# game_id                    int64
# game_name                 object
# game_des                  object
# game_yr_pub                int64
# min_players                int64
# max_players                int64
# min_play_time              int64
# max_play_time              int64
# min_age                    int64
# num_ratings                int64
# avg_rating               float64
# bayes_avg_rating         float64
# overall_rank_bayesavg     object
# family_rank_bayes         object
# complexity               float64
# categories                object
# mechanics                 object
# families                  object
# implementations           object
# designers                 object
# publishers                object
# dtype: object

# %% [markdown]
# ### Checking and Addressing Any Nulls
# This section focuses on addressing any and all nulls that may exist in the data frame.

# %%
df.isna().sum()
# Out:
# game_id                    0
# game_name                  0
# game_des                   0
# game_yr_pub                0
# min_players                0
# max_players                0
# min_play_time              0
# max_play_time              0
# min_age                    0
# num_ratings                0
# avg_rating                 0
# bayes_avg_rating           0
# overall_rank_bayesavg      0
# family_rank_bayes          0
# complexity                 0
# categories                 3
# mechanics                  0
# families                   8
# implementations          490
# designers                  1
# publishers                 0
# dtype: int64

# %% [markdown]
# Outside of 'implementations', there are a few NaNs in 'categories', 'families', and 'designers'. I am going to go through each of those features and check on [boardgamegeek.com](https://boardgamegeek.com) to see if it was missed for some reason, or if it really is empty, figure out what is appropriate to fill in the NaNs with.

# %%
df[df['categories'].isna()]
# Out:
#      game_id                       game_name  \
# 813   160851  Lanterns: The Harvest Festival
# 824   106217                          Hawaii
# 944   242684              Reavers of Midgard
#
#                                               game_des  game_yr_pub  \
# 813  The harvest is in, and the artisans are hard a...         2015
# 824  Game description from the publisher:&#10;&#10;...         2011
# 944  Reavers of Midgard is a single worker placemen...         2019
#
#      min_players  max_players  min_play_time  max_play_time  min_age  \
# 813            2            4             30             30        8
# 824            2            5             90             90       13
# 944            2            4             60            120       14
#
#      num_ratings  ...  bayes_avg_rating  overall_rank_bayesavg  \
# 813        10378  ...           6.66383            818|6.66383
# 824         4350  ...           6.65692            827|6.65692
# 944         2282  ...           6.58044            944|6.58044
#
#              family_rank_bayes complexity  categories  \
# 813     familygames/217/6.7173     1.5617         NaN
# 824  strategygames/481/6.76548     2.9024         NaN
# 944  strategygames/506/6.73192     2.9091         NaN
#
#                                              mechanics  \
# 813  Hand Management|Pattern Building|Set Collectio...
# 824  Action Points|Area Movement|Modular Board|Work...
# 944  Dice Rolling|Follow|Open Drafting|Set Collecti...
#
#                                               families  \
# 813  Country: China|Crowdfunding: Kickstarter|Game:...
# 824  Digital Implementations: Board Game Arena|Digi...
# 944  Admin: Better Description Needed!|Components: ...
#
#                       implementations          designers  \
# 813  Lanterns Dice: Lights in the Sky  Christopher Chung
# 824                               NaN        Greg Daigle
# 944                               NaN        J.B. Howell
#
#                                             publishers
# 813  Foxtrot Games|Renegade Game Studios|Broadway T...
# 824  Hans im Glück|999 Games|Filosofia Éditions|Rio...
# 944  Grey Fox Games|Arrakis Games|Corax Games|Don't...
#
# [3 rows x 21 columns]

# %% [markdown]
# For Lanterns: The Harvest Festival, the game is clearly a tile laying type game, but that is not a category. It also is not really a puzzle game. I don't want it to be without a category, so I am going with 'Abstract Strategy' since the rules appear to be straight forward and are their own thing.

# %%
df.loc[813, 'categories'] = 'Abstract Strategy'

# %% [markdown]
# For Hawaii, it has elements of 'Territory Building' and 'Economic' categorical features. As such, I will be adding them to the game so it doesn't get filtered out.

# %%
df.loc[824, 'categories'] = 'Territory Building|Economic'

# %% [markdown]
# Reavers of Midgard squarely fits in the 'Medieval' and 'Nautical' categories. You could argue a couple of others, but because I personally have not played it and can only glean so much from online reviews, I am sticking with the two categories that seem like obvious fits to me.

# %%
df.loc[944, 'categories'] = 'Mdeieval|Nautical'

# %%
df.loc[[813,824,944], 'categories']
# Out:
# 813              Abstract Strategy
# 824    Territory Building|Economic
# 944              Mdeieval|Nautical
# Name: categories, dtype: object

# %%
df[df['families'].isna()]
# Out:
#      game_id                   game_name  \
# 394    27162                   Kingsburg
# 451   202426         Sidereal Confluence
# 544   284435                   Nova Luna
# 595   296912                        Fort
# 664   192457                   Cry Havoc
# 823   301255            Whistle Mountain
# 881   199966  Kingsburg (Second Edition)
# 882   207691         Railroad Revolution
#
#                                               game_des  game_yr_pub  \
# 394  In Kingsburg, players are Lords sent from the ...         2007
# 451  Sidereal Confluence: Trading and Negotiation i...         2017
# 544  The new moon is a symbol for a new beginning, ...         2019
# 595  Fort is a 2-4 player card game about building ...         2020
# 664  Cry Havoc is a card-driven, asymmetric, area c...         2016
# 823  Whistle Stop designer Scott Caputo has teamed ...         2020
# 881  The realm of Kingsburg is under attack! Monstr...         2017
# 882  Ambition and a thirst for wealth have driven h...         2016
#
#      min_players  max_players  min_play_time  max_play_time  min_age  \
# 394            2            5             90             90       13
# 451            4            9            120            180       14
# 544            1            4             30             60        8
# 595            2            4             20             40       10
# 664            2            4             60            120       10
# 823            2            4             60             90       14
# 881            2            5             90            120       10
# 882            2            4             45             90       12
#
#      num_ratings  ...  bayes_avg_rating  overall_rank_bayesavg  \
# 394        18888  ...           7.01823            398|7.01823
# 451         3171  ...           6.95954            447|6.95954
# 544         4969  ...           6.87599            546|6.87599
# 595         5624  ...           6.81637            598|6.81637
# 664         6328  ...           6.76725            664|6.76725
# 823         1908  ...           6.67203            804|6.67203
# 881         2381  ...           6.61488            886|6.61488
# 882         2626  ...           6.61148            893|6.61148
#
#                                     family_rank_bayes complexity  \
# 394  strategygames/286/7.04281|familygames/87/7.05223     2.4254
# 451                         strategygames/240/7.13054     3.5504
# 544                               abstracts/16/7.1619     1.8667
# 595                          strategygames/384/6.8841     2.4286
# 664                         strategygames/418/6.84091     3.2707
# 823                         strategygames/399/6.86282     3.0000
# 881                          strategygames/493/6.7561     2.4493
# 882                         strategygames/484/6.76129     0.0000
#
#                                       categories  \
# 394          City Building|Dice|Fantasy|Medieval
# 451         Economic|Negotiation|Science Fiction
# 544                     Abstract Strategy|Puzzle
# 595                                    Card Game
# 664  Fighting|Miniatures|Science Fiction|Wargame
# 823                     Industry / Manufacturing
# 881          City Building|Dice|Fantasy|Medieval
# 882                                       Trains
#
#                                              mechanics families  \
# 394    Dice Rolling|Worker Placement with Dice Workers      NaN
# 451  Auction/Bidding|Negotiation|Trading|Variable P...      NaN
# 544           Contracts|Race|Tile Placement|Time Track      NaN
# 595  Deck, Bag, and Pool Building|Follow|Hand Manag...      NaN
# 664  Area Majority / Influence|Area Movement|Auctio...      NaN
# 823  Tile Placement|Variable Player Powers|Worker P...      NaN
# 881  Dice Rolling|Worker Placement|Worker Placement...      NaN
# 882  Network and Route Building|Worker Placement|Wo...      NaN
#
#                                        implementations  \
# 394  Kingsburg (Second Edition)|Kingsburg: The Dice...
# 451                                                NaN
# 544                                 Framework|Habitats
# 595                                               SPQF
# 664                                                NaN
# 823                                                NaN
# 881              Kingsburg|Kingsburg: To Forge a Realm
# 882                                                NaN
#
#                                     designers  \
# 394            Andrea Chiarvesio|Luca Iennaco
# 451                         TauCeti Deichmann
# 544           Uwe Rosenberg|Corné van Moorsel
# 595                              Grant Rodiek
# 664  Grant Rodiek|Michał Oracz|Michał Walczak
# 823                  Scott Caputo|Luke Laurie
# 881            Andrea Chiarvesio|Luca Iennaco
# 882          Marco Canetta|Stefania Niccolini
#
#                                             publishers
# 394  Stratelibri|Edge Entertainment|ElfinWerks|Fant...
# 451  WizKids (I)|Banana Games|Frosted Games|Intrafi...
# 544  Edition Spielwiese|Brädspel.se|Djama Games|Gam...
# 595  Leder Games|2Tomatoes Games|Asmodee|CrowD Game...
# 664  Portal Games|Edge Entertainment|Galápagos Jogo...
# 823  Bézier Games|BoardM Factory|La Boîte de Jeu|Ma...
# 881  Giochi Uniti|Stratelibri|Asmodee|Asmodee Korea...
# 882  What's Your Game?|hobbity.eu|Pegasus Spiele|Re...
#
# [8 rows x 21 columns]

# %% [markdown]
# Families is tricky because these are more detailed and specific to each game that I do not know having played none of them. Rather than guess at what might be best in a feature that I am leaning towards not implementing, I will fill the NaNs with blank strings.

# %%
df.loc[df[df['families'].isna()].index, 'families'] = ''

# %%
df[df['designers'].isna()]
# Out:
#      game_id                    game_name  \
# 879   165838  Space Hulk (Fourth Edition)
#
#                                               game_des  game_yr_pub  \
# 879  From the depths of space an ancient vessel dri...         2014
#
#      min_players  max_players  min_play_time  max_play_time  min_age  \
# 879            2            2             60             60       12
#
#      num_ratings  ...  bayes_avg_rating  overall_rank_bayesavg  \
# 879         1678  ...           6.61582            884|6.61582
#
#         family_rank_bayes complexity                           categories  \
# 879  thematic/133/6.98528     2.7093  Fighting|Miniatures|Science Fiction
#
#                                              mechanics  \
# 879  Action Points|Dice Rolling|Grid Movement|Modul...
#
#                                               families  \
# 879  Category: Dungeon Crawler|Game: Space Hulk|Pla...
#
#                 implementations designers           publishers
# 879  Space Hulk (Third Edition)       NaN  Games Workshop Ltd.
#
# [1 rows x 21 columns]

# %% [markdown]
# After looking online, this is the fourth edition of a game. There are no designers or artists listed online, and no designers for the third edition. As such, I am going to fill in `(Uncredited)` as the designer.

# %%
df.loc[879, 'designers'] = '(Uncredited)'
df.loc[879, 'designers']
# Out:
# '(Uncredited)'

# %% [markdown]
# The feature with the most NaNs, 'implementations', is going to be filled with blank string. 'Implementations' refers to when a game either uses the mechanics of a previous game or version of the same game, or is used as the base for a new game. If there is no implementation listed, then the game is a wholly unique version at this time.

# %%
df.fillna('', inplace=True)

# %%
df.isna().sum()
# Out:
# game_id                  0
# game_name                0
# game_des                 0
# game_yr_pub              0
# min_players              0
# max_players              0
# min_play_time            0
# max_play_time            0
# min_age                  0
# num_ratings              0
# avg_rating               0
# bayes_avg_rating         0
# overall_rank_bayesavg    0
# family_rank_bayes        0
# complexity               0
# categories               0
# mechanics                0
# families                 0
# implementations          0
# designers                0
# publishers               0
# dtype: int64

# %% [markdown]
# ### Generating Selection Lists
# After reviewing all of the features that I have collected, I think the ones that people are most likely to use are `game_yr_pub`, `min_players`, `max_players`, `min_play_time`, `max_play_time`, `min_age`, `avg_rating`, `complexity`, `categories`, `mechanics`, `designers`, and `publishers`. I will also include the game's name and id features as well, but they can go to the game page on boardgamegeek.com if they want to learn more. I am going to be dropping the other columns and generating a list of all the options for each feature to create filters for the app. I am also adding in a `rank` column using the `top1000_updated.csv` since that has the rankings from when I started the project.

# %%
rankings = pd.read_csv('../data/top1000_updated.csv')
rankings.head()
# Out:
#    rank                         title      id
# 0     1                    Gloomhaven  174430
# 1     2     Pandemic Legacy: Season 1  161936
# 2     3             Brass: Birmingham  224517
# 3     4             Terraforming Mars  167791
# 4     5  Gloomhaven: Jaws of the Lion  291457

# %%
recom = df.drop(columns=['game_des', 'num_ratings', 'bayes_avg_rating',
                         'overall_rank_bayesavg', 'family_rank_bayes', 'families',
                         'implementations']).copy()
recom
# Out:
#      game_id                       game_name  game_yr_pub  min_players  \
# 0     174430                      Gloomhaven         2017            1
# 1     161936       Pandemic Legacy: Season 1         2015            2
# 2     224517               Brass: Birmingham         2018            2
# 3     167791               Terraforming Mars         2016            1
# 4     291457    Gloomhaven: Jaws of the Lion         2020            1
# ..       ...                             ...          ...          ...
# 995    94246    1812: The Invasion of Canada         2012            2
# 996   163642                 Chimera Station         2017            2
# 997   156091  Sons of Anarchy: Men of Mayhem         2014            3
# 998    24068                  Shadow Hunters         2005            4
# 999    11971                 Cockroach Poker         2004            2
#
#      max_players  min_play_time  max_play_time  min_age  avg_rating  \
# 0              4             60            120       14     8.72850
# 1              4             60             60       13     8.58701
# 2              4             60            120       14     8.65880
# 3              5            120            120       12     8.41264
# 4              4             30            120       14     8.64682
# ..           ...            ...            ...      ...         ...
# 995            5             90             90       10     7.33553
# 996            4             60             90       13     7.30728
# 997            4             90             90       13     7.27311
# 998            8             60             60       10     6.81905
# 999            6             20             20        8     6.75665
#
#      complexity                                         categories  \
# 0        3.8728  Adventure|Exploration|Fantasy|Fighting|Miniatures
# 1        2.8302                              Environmental|Medical
# 2        3.9043  Economic|Industry / Manufacturing|Post-Napoleo...
# 3        3.2478  Economic|Environmental|Industry / Manufacturin...
# 4        3.5908  Adventure|Exploration|Fantasy|Fighting|Miniatures
# ..          ...                                                ...
# 995      2.1856           American Indian Wars|Educational|Wargame
# 996      3.1519                                    Science Fiction
# 997      2.5577  Mafia|Movies / TV / Radio theme|Negotiation|Te...
# 998      1.8189  Adventure|Bluffing|Card Game|Deduction|Horror|...
# 999      1.1118                      Bluffing|Card Game|Party Game
#
#                                              mechanics  \
# 0    Action Queue|Action Retrieval|Campaign / Battl...
# 1    Action Points|Cooperative Game|Hand Management...
# 2    Hand Management|Income|Loans|Market|Network an...
# 3    Closed Drafting|Contracts|Enclosure|End Game B...
# 4    Action Queue|Action Retrieval|Campaign / Battl...
# ..                                                 ...
# 995  Area Movement|Campaign / Battle Card Driven|Di...
# 996  Tile Placement|Turn Order: Claim Action|Variab...
# 997  Action Points|Area Majority / Influence|Dice R...
# 998  Dice Rolling|Hidden Roles|Player Elimination|T...
# 999   Hand Management|Set Collection|Single Loser Game
#
#                                    designers  \
# 0                             Isaac Childres
# 1                    Rob Daviau|Matt Leacock
# 2     Gavan Brown|Matt Tolman|Martin Wallace
# 3                            Jacob Fryxelius
# 4                             Isaac Childres
# ..                                       ...
# 995                  Beau Beckett|Jeph Stahl
# 996                               Mark Major
# 997  Aaron Dill|John Kovaleski|Sean Sweigart
# 998                           Yasutaka Ikeda
# 999                           Jacques Zeimet
#
#                                             publishers
# 0    Cephalofair Games|Albi|Albi Polska|Arclight|As...
# 1    Z-Man Games|Asterion Press|Devir|Filosofia Édi...
# 2    Roxley|Arclight|BoardM Factory|Conclave Editor...
# 3    FryxGames|Arclight|Brädspel.se|Fantasmagoria|G...
# 4    Cephalofair Games|Albi|Albi Polska|Asmodee|Asm...
# ..                                                 ...
# 995  Academy Games, Inc.|ASYNCRON games|Schwerkraft...
# 996                   Tasty Minstrel Games|Game Brewer
# 997    Gale Force Nine, LLC|Battlefront Miniatures Ltd
# 998  Game Republic, Inc.|cosaic|Giochi Uniti|Kaissa...
# 999  Drei Magier Spiele|ADC Blackfire Entertainment...
#
# [1000 rows x 14 columns]

# %%
recom = pd.merge(recom, rankings, left_on='game_id', right_on='id').drop(columns=['title', 'id'])
recom.head()
# Out:
#    game_id                     game_name  game_yr_pub  min_players  \
# 0   174430                    Gloomhaven         2017            1
# 1   161936     Pandemic Legacy: Season 1         2015            2
# 2   224517             Brass: Birmingham         2018            2
# 3   167791             Terraforming Mars         2016            1
# 4   291457  Gloomhaven: Jaws of the Lion         2020            1
#
#    max_players  min_play_time  max_play_time  min_age  avg_rating  complexity  \
# 0            4             60            120       14     8.72850      3.8728
# 1            4             60             60       13     8.58701      2.8302
# 2            4             60            120       14     8.65880      3.9043
# 3            5            120            120       12     8.41264      3.2478
# 4            4             30            120       14     8.64682      3.5908
#
#                                           categories  \
# 0  Adventure|Exploration|Fantasy|Fighting|Miniatures
# 1                              Environmental|Medical
# 2  Economic|Industry / Manufacturing|Post-Napoleo...
# 3  Economic|Environmental|Industry / Manufacturin...
# 4  Adventure|Exploration|Fantasy|Fighting|Miniatures
#
#                                            mechanics  \
# 0  Action Queue|Action Retrieval|Campaign / Battl...
# 1  Action Points|Cooperative Game|Hand Management...
# 2  Hand Management|Income|Loans|Market|Network an...
# 3  Closed Drafting|Contracts|Enclosure|End Game B...
# 4  Action Queue|Action Retrieval|Campaign / Battl...
#
#                                 designers  \
# 0                          Isaac Childres
# 1                 Rob Daviau|Matt Leacock
# 2  Gavan Brown|Matt Tolman|Martin Wallace
# 3                         Jacob Fryxelius
# 4                          Isaac Childres
#
#                                           publishers  rank
# 0  Cephalofair Games|Albi|Albi Polska|Arclight|As...     1
# 1  Z-Man Games|Asterion Press|Devir|Filosofia Édi...     2
# 2  Roxley|Arclight|BoardM Factory|Conclave Editor...     3
# 3  FryxGames|Arclight|Brädspel.se|Fantasmagoria|G...     4
# 4  Cephalofair Games|Albi|Albi Polska|Asmodee|Asm...     5

# %%
recom['game_yr_pub'].min(), recom['game_yr_pub'].max()
# There appears to be a -2200 for a game year, so I am looing into that a bit.
# Out:
# (-2200, 2021)

# %%
recom.sort_values('game_yr_pub').head(10)
# These make sense now. Going to leave it alone for now. I may have to get creative in the app later
# Out:
#      game_id     game_name  game_yr_pub  min_players  max_players  \
# 189      188            Go        -2200            2            2
# 432      171         Chess         1475            2            2
# 640     2398      Cribbage         1630            2            4
# 732       45        Perudo         1800            2            6
# 821     2093       Mahjong         1850            3            4
# 58       521     Crokinole         1876            2            4
# 793     2181        Bridge         1925            4            4
# 665      483     Diplomacy         1959            2            7
# 299        5       Acquire         1964            2            6
# 706     1035  Squad Leader         1977            2            2
#
#      min_play_time  max_play_time  min_age  avg_rating  complexity  \
# 189             30            180        8     7.63939      3.9386
# 432              0              0        6     7.16095      3.6826
# 640             30             30       10     7.07419      1.9024
# 732             15             30        8     6.90609      1.2605
# 821            120            120        8     7.03181      2.5681
# 58              30             30        8     7.96301      1.2480
# 793             60             60       12     7.45893      3.8610
# 665            360            360       12     7.04085      3.3493
# 299             90             90       12     7.33844      2.5003
# 706             60             60       14     7.53212      4.0363
#
#                                             categories  \
# 189                                  Abstract Strategy
# 432                                  Abstract Strategy
# 640                                          Card Game
# 732  Bluffing|Dice|Movies / TV / Radio theme|Party ...
# 821                                  Abstract Strategy
# 58                                  Action / Dexterity
# 793                                          Card Game
# 665  Bluffing|Negotiation|Political|Post-Napoleonic...
# 299                        Economic|Territory Building
# 706                               Wargame|World War II
#
#                                              mechanics          designers  \
# 189                              Enclosure|Square Grid       (Uncredited)
# 432  Grid Movement|Pattern Movement|Square Grid|Sta...       (Uncredited)
# 640                     Hand Management|Push Your Luck  Sir John Suckling
# 732  Betting and Bluffing|Dice Rolling|Player Elimi...       Richard Borg
# 821                     Hand Management|Set Collection       (Uncredited)
# 58                            Flicking|Team-Based Game       (Uncredited)
# 793  Auction/Bidding|Hand Management|Predictive Bid...  Harold Vanderbilt
# 665  Area Majority / Influence|Area Movement|Negoti...  Allan B. Calhamer
# 299  Hand Management|Investment|Market|Square Grid|...        Sid Sackson
# 706  Critical Hits and Failures|Dice Rolling|Events...      John Hill (I)
#
#                                             publishers  rank
# 189  (Public Domain)|(Self-Published)|(Unknown)|3M|...   190
# 432  (Public Domain)|(Self-Published)|(Unknown)|3M|...   433
# 640  (Public Domain)|(Unknown)|5th Peg|Acme Ruler C...   641
# 732  (Public Domain)|Endless Games (I)|F.X. Schmid|...   733
# 821  (Public Domain)|(Unknown)|A. D. Richter & Cie....   822
# 58   (Public Domain)|(Unknown)|BrownCastle Games|Ca...    59
# 793  (Public Domain)|Ariel Productions Ltd|ASS Alte...   794
# 665  The Avalon Hill Game Co|Games Research, Inc.|(...   666
# 299  3M|The Avalon Hill Game Co|Avalon Hill Games, ...   300
# 706  Arsenal Publishing, Inc.|The Avalon Hill Game ...   707

# %%
recom['min_players'].value_counts(),
# Out:
# (2    614
#  1    286
#  3     79
#  4     16
#  5      4
#  6      1
#  Name: min_players, dtype: int64,)

# %%
recom['max_players'].value_counts()
# Out:
# 4      449
# 5      234
# 2      114
# 6      110
# 8       32
# 7       21
# 10      10
# 3        9
# 1        7
# 12       6
# 100      2
# 18       2
# 16       1
# 9        1
# 99       1
# 30       1
# Name: max_players, dtype: int64

# %%
recom['min_play_time'].value_counts(bins=[0, 15, 30, 45, 60, 480])
# These bins help narrow things down and aren't overwhelming.
# Out:
# (15.0, 30.0]      259
# (60.0, 480.0]     256
# (45.0, 60.0]      254
# (30.0, 45.0]      175
# (-0.001, 15.0]     56
# Name: min_play_time, dtype: int64

# %%
recom['max_play_time'].value_counts(bins=[0, 30, 60, 90, 120, 1250])
# These bins will work if max time is used.
# Out:
# (30.0, 60.0]       325
# (60.0, 90.0]       176
# (-0.001, 30.0]     170
# (90.0, 120.0]      169
# (120.0, 1250.0]    160
# Name: max_play_time, dtype: int64

# %%
recom['min_age'].value_counts().sort_index()
# Out:
# 0       2
# 4       1
# 5       2
# 6       5
# 7       9
# 8     144
# 9      20
# 10    173
# 11      4
# 12    263
# 13    119
# 14    247
# 15      4
# 16      1
# 17      5
# 18      1
# Name: min_age, dtype: int64

# %%
recom['avg_rating'].min(), recom['avg_rating'].max()
# Out:
# (6.6688, 8.81379)

# %%
recom['complexity'].min(), recom['complexity'].max()
# Out:
# (0.0, 4.7359)

# %%
recom[recom['complexity'] == 0.0]
# These games do have weights (what I call `complexity`), so I will fill them in.
# Out:
#      game_id                                          game_name  game_yr_pub  \
# 115     2511  Sherlock Holmes Consulting Detective: The Tham...         1982
# 118   175155                                    Forbidden Stars         2015
# 177   189932                           Tyrants of the Underdark         2016
# 191       12                                                 Ra         1999
# 198   209418                          Dominion (Second Edition)         2016
# 270    48726                                    Alien Frontiers         2010
# 279   139976                                       Cthulhu Wars         2015
# 291   172818                                    Above and Below         2015
# 304   176920               Mission: Red Planet (Second Edition)         2015
# 312   163745                                  Star Wars: Armada         2015
# 332   250458                                             Gùgōng         2018
# 338   244271             Dice Throne: Season Two – Battle Chest         2018
# 365    54625                         Space Hulk (Third Edition)         2009
# 382   138161                                  Firefly: The Game         2013
# 411    62222                     Commands & Colors: Napoleonics         2010
# 418    17226                      Descent: Journeys in the Dark         2005
# 427    62227             Labyrinth: The War on Terror, 2001 – ?         2010
# 460   133848                  Euphoria: Build a Better Dystopia         2013
# 509    84419                                   Space Empires 4X         2011
# 530   175095                   Dawn of the Zeds (Third Edition)         2016
# 574   111799                                         Cuba Libre         2013
# 594   245961                               Fleet: The Dice Game         2018
# 596   113294                    Escape: The Curse of the Temple         2012
# 718    12002                                              Jambo         2004
# 728   256570                                     Crown of Emara         2018
# 784    91514                                         Rhino Hero         2011
# 831   272738                                               Jaws         2019
# 849   254386                                     Raccoon Tycoon         2018
# 882   207691                                Railroad Revolution         2016
#
#      min_players  max_players  min_play_time  max_play_time  min_age  \
# 115            1            8             60            120       13
# 118            2            4            120            180       14
# 177            2            4             60             60       14
# 191            2            5             45             60       12
# 198            2            4             30             30       14
# 270            2            4             90             90       13
# 279            2            4             90            120       14
# 291            2            4             90             90       13
# 304            2            6             45             90       14
# 312            2            2            120            120       14
# 332            1            5             60             90       12
# 338            2            6             20             40        8
# 365            2            2             60             60       12
# 382            1            4            120            240       13
# 411            2            2             90             90       14
# 418            2            5            120            240       13
# 427            1            2            180            180       12
# 460            2            6             60             60       13
# 509            1            4            180            180       12
# 530            1            5             90            120       14
# 574            1            4            180            180       14
# 594            1            4             30             45        8
# 596            1            5             10             10        8
# 718            2            2             45             45       12
# 728            1            4             45             75       12
# 784            2            5              5             15        5
# 831            2            4             60             60       12
# 849            2            5             60             90        8
# 882            2            4             45             90       12
#
#      avg_rating  complexity  \
# 115     7.69245         0.0
# 118     7.96961         0.0
# 177     7.91580         0.0
# 191     7.48443         0.0
# 198     7.89540         0.0
# 270     7.39179         0.0
# 279     7.89068         0.0
# 291     7.39490         0.0
# 304     7.43791         0.0
# 312     7.83425         0.0
# 332     7.49728         0.0
# 338     8.13462         0.0
# 365     7.53162         0.0
# 382     7.39171         0.0
# 411     8.01320         0.0
# 418     7.29255         0.0
# 427     7.58857         0.0
# 460     7.23186         0.0
# 509     7.70712         0.0
# 530     8.18462         0.0
# 574     7.69566         0.0
# 594     7.74062         0.0
# 596     6.98261         0.0
# 718     6.99908         0.0
# 728     7.45366         0.0
# 784     6.93333         0.0
# 831     7.20077         0.0
# 849     7.36563         0.0
# 882     7.35658         0.0
#
#                                             categories  \
# 115  Deduction|Murder/Mystery|Novel-based|Post-Napo...
# 118  Bluffing|Fighting|Miniatures|Science Fiction|W...
# 177                                   Fantasy|Fighting
# 191                                  Ancient|Mythology
# 198                                 Card Game|Medieval
# 270                               Dice|Science Fiction
# 279                 Fantasy|Fighting|Horror|Miniatures
# 291  Adventure|City Building|Economic|Exploration|F...
# 304                                    Science Fiction
# 312  Collectible Components|Miniatures|Movies / TV ...
# 332                                    Medieval|Travel
# 338                    Card Game|Dice|Fantasy|Fighting
# 365        Fighting|Miniatures|Science Fiction|Wargame
# 382  Adventure|Movies / TV / Radio theme|Science Fi...
# 411                                 Napoleonic|Wargame
# 418  Adventure|Exploration|Fantasy|Fighting|Miniatures
# 427           Arabian|Modern Warfare|Political|Wargame
# 460                                    Science Fiction
# 509  Bluffing|Civilization|Science Fiction|Space Ex...
# 530                                     Horror|Zombies
# 574          Economic|Modern Warfare|Political|Wargame
# 594                                      Dice|Nautical
# 596  Action / Dexterity|Adventure|Dice|Electronic|E...
# 718                                 Card Game|Economic
# 728                                  Economic|Medieval
# 784  Action / Dexterity|Animals|Children's Game|Par...
# 831  Animals|Fighting|Movies / TV / Radio theme|Nau...
# 849                                   Animals|Economic
# 882                                             Trains
#
#                                              mechanics  \
# 115  Cooperative Game|Narrative Choice / Paragraph|...
# 118  Area Majority / Influence|Area Movement|Card P...
# 177  Area Majority / Influence|Connections|Deck, Ba...
# 191  Auction/Bidding|Auction: Once Around|Closed Ec...
# 198  Deck, Bag, and Pool Building|Hand Management|O...
# 270  Area Majority / Influence|Dice Rolling|Open Dr...
# 279  Action Points|Area Majority / Influence|Area M...
# 291  Action Points|Dice Rolling|Narrative Choice / ...
# 304  Action Retrieval|Area Majority / Influence|Are...
# 312  Action Queue|Critical Hits and Failures|Dice R...
# 332  Area Majority / Influence|Hand Management|Set ...
# 338  Dice Rolling|Take That|Team-Based Game|Variabl...
# 365  Action Points|Dice Rolling|Grid Movement|Modul...
# 382  Area Movement|Dice Rolling|Open Drafting|Pick-...
# 411  Campaign / Battle Card Driven|Command Cards|Di...
# 418  Dice Rolling|Grid Movement|Modular Board|Role ...
# 427  Action Points|Action/Event|Area Majority / Inf...
# 460  Dice Rolling|Hand Management|Race|Set Collecti...
# 509  Auction/Bidding|Dice Rolling|Grid Movement|Hex...
# 530  Action Points|Campaign / Battle Card Driven|Co...
# 574  Area Majority / Influence|Area Movement|Dice R...
# 594  Dice Rolling|Paper-and-Pencil|Solo / Solitaire...
# 596  Cooperative Game|Dice Rolling|Elapsed Real Tim...
# 718  Action Points|Contracts|Hand Management|Set Co...
# 728  Action Queue|Hand Management|Highest-Lowest Sc...
# 784  Hand Management|Lose a Turn|Stacking and Balan...
# 831  Action Points|Area Movement|Card Play Conflict...
# 849  Auction/Bidding|Auction: Turn Order Until Pass...
# 882  Network and Route Building|Worker Placement|Wo...
#
#                                        designers  \
# 115  Raymond Edwards|Suzanne Goldberg|Gary Grady
# 118  Samuel Bailey|James Kniffen|Corey Konieczka
# 177        Peter Lee|Rodney Thompson|Andrew Veen
# 191                                Reiner Knizia
# 198                          Donald X. Vaccarino
# 270                                 Tory Niemann
# 279              Sandy Petersen|Lincoln Petersen
# 291                                  Ryan Laukat
# 304                 Bruno Cathala|Bruno Faidutti
# 312          James Kniffen|Christian T. Petersen
# 332                              Andreas Steding
# 338               Nate Chatellier|Manny Trembley
# 365                            Richard Halliwell
# 382      Aaron Dill|John Kovaleski|Sean Sweigart
# 411                                 Richard Borg
# 418                                 Kevin Wilson
# 427                                 Volko Ruhnke
# 460                   Jamey Stegmaier|Alan Stone
# 509                                    Jim Krohn
# 530                             Hermann Luttmann
# 574                   Jeff Grossman|Volko Ruhnke
# 594                    Ben Pinchback|Matt Riddle
# 596                      Kristian Amundsen Østby
# 718                                 Rüdiger Dorn
# 728                              Benjamin Schwer
# 784                  Scott Frisco|Steven Strumpf
# 831                                Prospero Hall
# 849                                 Glenn Drover
# 882             Marco Canetta|Stefania Niccolini
#
#                                             publishers  rank
# 115  Sleuth Publications|Space Cowboys|Angry Lion G...   116
# 118  Fantasy Flight Games|Asterion Press|Edge Enter...   119
# 177  Gale Force Nine, LLC|Heidelberger Spieleverlag...   178
# 191  alea|Ravensburger|25th Century Games|999 Games...   192
# 198  Rio Grande Games|999 Games|Conclave Editora|De...   199
# 270  Clever Mojo Games|Game Salute|Hobby World|LocW...   271
# 279  Petersen Games|Arclight|BoardM Factory|Fabrika...   280
# 291  Red Raven Games|Arclight|Bard Centrum Gier|Con...   292
# 304  Fantasy Flight Games|Edge Entertainment|Galakt...   305
# 312  Fantasy Flight Games|Edge Entertainment|Galakt...   313
# 332  Game Brewer|CrowD Games|Delta Vision Publishin...   333
# 338                   Lucky Duck Games|Rawstone|Roxley   339
# 365                                Games Workshop Ltd.   366
# 382  Gale Force Nine, LLC|Battlefront Miniatures Lt...   383
# 411                                          GMT Games   412
# 418  Fantasy Flight Games|Arclight|Delta Vision Pub...   419
# 427  GMT Games|Asterion Press|Bard Centrum Gier|Udo...   428
# 460  Stonemaier Games|ADC Blackfire Entertainment|A...   461
# 509                             GMT Games|Banana Games   510
# 530    Victory Point Games|Frosted Games|Maldito Games   531
# 574                             GMT Games|Banana Games   575
# 594  Eagle-Gryphon Games|Dice High Company|FRED Dis...   595
# 596           Queen Games|Brädspel.se|Rebel Sp. z o.o.   597
# 718  KOSMOS|Filosofia Éditions|MINDOK|Quined White ...   719
# 728  Pegasus Spiele|999 Games|Ediciones MasQueOca|H...   729
# 784  HABA|Hobby World|Korea Boardgames Co., Ltd.|Na...   785
# 831                                       Ravensburger   832
# 849  Forbidden Games|Arrakis Games|Pendragon Game S...   850
# 882  What's Your Game?|hobbity.eu|Pegasus Spiele|Re...   883

# %%
fix = recom[recom['complexity'] == 0.0].index
fix
# Out:
# Int64Index([115, 118, 177, 191, 198, 270, 279, 291, 304, 312, 332, 338, 365,
#             382, 411, 418, 427, 460, 509, 530, 574, 594, 596, 718, 728, 784,
#             831, 849, 882],
#            dtype='int64')

# %%
recom.loc[115, 'complexity'] = 2.67
recom.loc[118, 'complexity'] = 3.83
recom.loc[177, 'complexity'] = 2.55
recom.loc[191, 'complexity'] = 2.35
recom.loc[198, 'complexity'] = 2.16
recom.loc[270, 'complexity'] = 2.57
recom.loc[279, 'complexity'] = 3.15
recom.loc[291, 'complexity'] = 2.52
recom.loc[304, 'complexity'] = 2.20
recom.loc[312, 'complexity'] = 3.15
recom.loc[332, 'complexity'] = 3.10
recom.loc[338, 'complexity'] = 2.16
recom.loc[365, 'complexity'] = 2.78
recom.loc[382, 'complexity'] = 2.96
recom.loc[411, 'complexity'] = 2.74
recom.loc[418, 'complexity'] = 3.34
recom.loc[427, 'complexity'] = 3.63
recom.loc[460, 'complexity'] = 3.12
recom.loc[509, 'complexity'] = 3.38
recom.loc[530, 'complexity'] = 3.80
recom.loc[574, 'complexity'] = 3.55
recom.loc[594, 'complexity'] = 2.58
recom.loc[596, 'complexity'] = 1.48
recom.loc[718, 'complexity'] = 2.07
recom.loc[728, 'complexity'] = 3.09
recom.loc[784, 'complexity'] = 1.02
recom.loc[831, 'complexity'] = 2.19
recom.loc[849, 'complexity'] = 2.08
recom.loc[882, 'complexity'] = 3.26

# %%
recom.loc[fix]
# Out:
#      game_id                                          game_name  game_yr_pub  \
# 115     2511  Sherlock Holmes Consulting Detective: The Tham...         1982
# 118   175155                                    Forbidden Stars         2015
# 177   189932                           Tyrants of the Underdark         2016
# 191       12                                                 Ra         1999
# 198   209418                          Dominion (Second Edition)         2016
# 270    48726                                    Alien Frontiers         2010
# 279   139976                                       Cthulhu Wars         2015
# 291   172818                                    Above and Below         2015
# 304   176920               Mission: Red Planet (Second Edition)         2015
# 312   163745                                  Star Wars: Armada         2015
# 332   250458                                             Gùgōng         2018
# 338   244271             Dice Throne: Season Two – Battle Chest         2018
# 365    54625                         Space Hulk (Third Edition)         2009
# 382   138161                                  Firefly: The Game         2013
# 411    62222                     Commands & Colors: Napoleonics         2010
# 418    17226                      Descent: Journeys in the Dark         2005
# 427    62227             Labyrinth: The War on Terror, 2001 – ?         2010
# 460   133848                  Euphoria: Build a Better Dystopia         2013
# 509    84419                                   Space Empires 4X         2011
# 530   175095                   Dawn of the Zeds (Third Edition)         2016
# 574   111799                                         Cuba Libre         2013
# 594   245961                               Fleet: The Dice Game         2018
# 596   113294                    Escape: The Curse of the Temple         2012
# 718    12002                                              Jambo         2004
# 728   256570                                     Crown of Emara         2018
# 784    91514                                         Rhino Hero         2011
# 831   272738                                               Jaws         2019
# 849   254386                                     Raccoon Tycoon         2018
# 882   207691                                Railroad Revolution         2016
#
#      min_players  max_players  min_play_time  max_play_time  min_age  \
# 115            1            8             60            120       13
# 118            2            4            120            180       14
# 177            2            4             60             60       14
# 191            2            5             45             60       12
# 198            2            4             30             30       14
# 270            2            4             90             90       13
# 279            2            4             90            120       14
# 291            2            4             90             90       13
# 304            2            6             45             90       14
# 312            2            2            120            120       14
# 332            1            5             60             90       12
# 338            2            6             20             40        8
# 365            2            2             60             60       12
# 382            1            4            120            240       13
# 411            2            2             90             90       14
# 418            2            5            120            240       13
# 427            1            2            180            180       12
# 460            2            6             60             60       13
# 509            1            4            180            180       12
# 530            1            5             90            120       14
# 574            1            4            180            180       14
# 594            1            4             30             45        8
# 596            1            5             10             10        8
# 718            2            2             45             45       12
# 728            1            4             45             75       12
# 784            2            5              5             15        5
# 831            2            4             60             60       12
# 849            2            5             60             90        8
# 882            2            4             45             90       12
#
#      avg_rating  complexity  \
# 115     7.69245        2.67
# 118     7.96961        3.83
# 177     7.91580        2.55
# 191     7.48443        2.35
# 198     7.89540        2.16
# 270     7.39179        2.57
# 279     7.89068        3.15
# 291     7.39490        2.52
# 304     7.43791        2.20
# 312     7.83425        3.15
# 332     7.49728        3.10
# 338     8.13462        2.16
# 365     7.53162        2.78
# 382     7.39171        2.96
# 411     8.01320        2.74
# 418     7.29255        3.34
# 427     7.58857        3.63
# 460     7.23186        3.12
# 509     7.70712        3.38
# 530     8.18462        3.80
# 574     7.69566        3.55
# 594     7.74062        2.58
# 596     6.98261        1.48
# 718     6.99908        2.07
# 728     7.45366        3.09
# 784     6.93333        1.02
# 831     7.20077        2.19
# 849     7.36563        2.08
# 882     7.35658        3.26
#
#                                             categories  \
# 115  Deduction|Murder/Mystery|Novel-based|Post-Napo...
# 118  Bluffing|Fighting|Miniatures|Science Fiction|W...
# 177                                   Fantasy|Fighting
# 191                                  Ancient|Mythology
# 198                                 Card Game|Medieval
# 270                               Dice|Science Fiction
# 279                 Fantasy|Fighting|Horror|Miniatures
# 291  Adventure|City Building|Economic|Exploration|F...
# 304                                    Science Fiction
# 312  Collectible Components|Miniatures|Movies / TV ...
# 332                                    Medieval|Travel
# 338                    Card Game|Dice|Fantasy|Fighting
# 365        Fighting|Miniatures|Science Fiction|Wargame
# 382  Adventure|Movies / TV / Radio theme|Science Fi...
# 411                                 Napoleonic|Wargame
# 418  Adventure|Exploration|Fantasy|Fighting|Miniatures
# 427           Arabian|Modern Warfare|Political|Wargame
# 460                                    Science Fiction
# 509  Bluffing|Civilization|Science Fiction|Space Ex...
# 530                                     Horror|Zombies
# 574          Economic|Modern Warfare|Political|Wargame
# 594                                      Dice|Nautical
# 596  Action / Dexterity|Adventure|Dice|Electronic|E...
# 718                                 Card Game|Economic
# 728                                  Economic|Medieval
# 784  Action / Dexterity|Animals|Children's Game|Par...
# 831  Animals|Fighting|Movies / TV / Radio theme|Nau...
# 849                                   Animals|Economic
# 882                                             Trains
#
#                                              mechanics  \
# 115  Cooperative Game|Narrative Choice / Paragraph|...
# 118  Area Majority / Influence|Area Movement|Card P...
# 177  Area Majority / Influence|Connections|Deck, Ba...
# 191  Auction/Bidding|Auction: Once Around|Closed Ec...
# 198  Deck, Bag, and Pool Building|Hand Management|O...
# 270  Area Majority / Influence|Dice Rolling|Open Dr...
# 279  Action Points|Area Majority / Influence|Area M...
# 291  Action Points|Dice Rolling|Narrative Choice / ...
# 304  Action Retrieval|Area Majority / Influence|Are...
# 312  Action Queue|Critical Hits and Failures|Dice R...
# 332  Area Majority / Influence|Hand Management|Set ...
# 338  Dice Rolling|Take That|Team-Based Game|Variabl...
# 365  Action Points|Dice Rolling|Grid Movement|Modul...
# 382  Area Movement|Dice Rolling|Open Drafting|Pick-...
# 411  Campaign / Battle Card Driven|Command Cards|Di...
# 418  Dice Rolling|Grid Movement|Modular Board|Role ...
# 427  Action Points|Action/Event|Area Majority / Inf...
# 460  Dice Rolling|Hand Management|Race|Set Collecti...
# 509  Auction/Bidding|Dice Rolling|Grid Movement|Hex...
# 530  Action Points|Campaign / Battle Card Driven|Co...
# 574  Area Majority / Influence|Area Movement|Dice R...
# 594  Dice Rolling|Paper-and-Pencil|Solo / Solitaire...
# 596  Cooperative Game|Dice Rolling|Elapsed Real Tim...
# 718  Action Points|Contracts|Hand Management|Set Co...
# 728  Action Queue|Hand Management|Highest-Lowest Sc...
# 784  Hand Management|Lose a Turn|Stacking and Balan...
# 831  Action Points|Area Movement|Card Play Conflict...
# 849  Auction/Bidding|Auction: Turn Order Until Pass...
# 882  Network and Route Building|Worker Placement|Wo...
#
#                                        designers  \
# 115  Raymond Edwards|Suzanne Goldberg|Gary Grady
# 118  Samuel Bailey|James Kniffen|Corey Konieczka
# 177        Peter Lee|Rodney Thompson|Andrew Veen
# 191                                Reiner Knizia
# 198                          Donald X. Vaccarino
# 270                                 Tory Niemann
# 279              Sandy Petersen|Lincoln Petersen
# 291                                  Ryan Laukat
# 304                 Bruno Cathala|Bruno Faidutti
# 312          James Kniffen|Christian T. Petersen
# 332                              Andreas Steding
# 338               Nate Chatellier|Manny Trembley
# 365                            Richard Halliwell
# 382      Aaron Dill|John Kovaleski|Sean Sweigart
# 411                                 Richard Borg
# 418                                 Kevin Wilson
# 427                                 Volko Ruhnke
# 460                   Jamey Stegmaier|Alan Stone
# 509                                    Jim Krohn
# 530                             Hermann Luttmann
# 574                   Jeff Grossman|Volko Ruhnke
# 594                    Ben Pinchback|Matt Riddle
# 596                      Kristian Amundsen Østby
# 718                                 Rüdiger Dorn
# 728                              Benjamin Schwer
# 784                  Scott Frisco|Steven Strumpf
# 831                                Prospero Hall
# 849                                 Glenn Drover
# 882             Marco Canetta|Stefania Niccolini
#
#                                             publishers  rank
# 115  Sleuth Publications|Space Cowboys|Angry Lion G...   116
# 118  Fantasy Flight Games|Asterion Press|Edge Enter...   119
# 177  Gale Force Nine, LLC|Heidelberger Spieleverlag...   178
# 191  alea|Ravensburger|25th Century Games|999 Games...   192
# 198  Rio Grande Games|999 Games|Conclave Editora|De...   199
# 270  Clever Mojo Games|Game Salute|Hobby World|LocW...   271
# 279  Petersen Games|Arclight|BoardM Factory|Fabrika...   280
# 291  Red Raven Games|Arclight|Bard Centrum Gier|Con...   292
# 304  Fantasy Flight Games|Edge Entertainment|Galakt...   305
# 312  Fantasy Flight Games|Edge Entertainment|Galakt...   313
# 332  Game Brewer|CrowD Games|Delta Vision Publishin...   333
# 338                   Lucky Duck Games|Rawstone|Roxley   339
# 365                                Games Workshop Ltd.   366
# 382  Gale Force Nine, LLC|Battlefront Miniatures Lt...   383
# 411                                          GMT Games   412
# 418  Fantasy Flight Games|Arclight|Delta Vision Pub...   419
# 427  GMT Games|Asterion Press|Bard Centrum Gier|Udo...   428
# 460  Stonemaier Games|ADC Blackfire Entertainment|A...   461
# 509                             GMT Games|Banana Games   510
# 530    Victory Point Games|Frosted Games|Maldito Games   531
# 574                             GMT Games|Banana Games   575
# 594  Eagle-Gryphon Games|Dice High Company|FRED Dis...   595
# 596           Queen Games|Brädspel.se|Rebel Sp. z o.o.   597
# 718  KOSMOS|Filosofia Éditions|MINDOK|Quined White ...   719
# 728  Pegasus Spiele|999 Games|Ediciones MasQueOca|H...   729
# 784  HABA|Hobby World|Korea Boardgames Co., Ltd.|Na...   785
# 831                                       Ravensburger   832
# 849  Forbidden Games|Arrakis Games|Pendragon Game S...   850
# 882  What's Your Game?|hobbity.eu|Pegasus Spiele|Re...   883

# %%
recom['complexity'].min(), recom['complexity'].max()
# Out:
# (1.02, 4.7359)

# %%
categories = []
for row in recom['categories']:
    categories += row.split('|')
set(categories)
# Out:
# {'Abstract Strategy',
#  'Action / Dexterity',
#  'Adventure',
#  'Age of Reason',
#  'American Civil War',
#  'American Indian Wars',
#  'American Revolutionary War',
#  'American West',
#  'Ancient',
#  'Animals',
#  'Arabian',
#  'Aviation / Flight',
#  'Bluffing',
#  'Card Game',
#  "Children's Game",
#  'City Building',
#  'Civil War',
#  'Civilization',
#  'Collectible Components',
#  'Comic Book / Strip',
#  'Deduction',
#  'Dice',
#  'Economic',
#  'Educational',
#  'Electronic',
#  'Environmental',
#  'Expansion for Base-game',
#  'Exploration',
#  'Fantasy',
#  'Farming',
#  'Fighting',
#  'Horror',
#  'Humor',
#  'Industry / Manufacturing',
#  'Mafia',
#  'Math',
#  'Mature / Adult',
#  'Maze',
#  'Mdeieval',
#  'Medical',
#  'Medieval',
#  'Memory',
#  'Miniatures',
#  'Modern Warfare',
#  'Movies / TV / Radio theme',
#  'Murder/Mystery',
#  'Mythology',
#  'Napoleonic',
#  'Nautical',
#  'Negotiation',
#  'Novel-based',
#  'Number',
#  'Party Game',
#  'Pike and Shot',
#  'Pirates',
#  'Political',
#  'Post-Napoleonic',
#  'Prehistoric',
#  'Print & Play',
#  'Puzzle',
#  'Racing',
#  'Real-time',
#  'Religious',
#  'Renaissance',
#  'Science Fiction',
#  'Space Exploration',
#  'Spies/Secret Agents',
#  'Sports',
#  'Territory Building',
#  'Trains',
#  'Transportation',
#  'Travel',
#  'Trivia',
#  'Video Game Theme',
#  'Vietnam War',
#  'Wargame',
#  'Word Game',
#  'World War I',
#  'World War II',
#  'Zombies'}

# %%
mechanics = []
for row in recom['mechanics']:
    mechanics += row.split('|')
set(mechanics)
# Out:
# {'Acting',
#  'Action Drafting',
#  'Action Points',
#  'Action Queue',
#  'Action Retrieval',
#  'Action Timer',
#  'Action/Event',
#  'Advantage Token',
#  'Alliances',
#  'Area Majority / Influence',
#  'Area Movement',
#  'Area-Impulse',
#  'Auction/Bidding',
#  'Auction: Dutch',
#  'Auction: Dutch Priority',
#  'Auction: English',
#  'Auction: Fixed Placement',
#  'Auction: Once Around',
#  'Auction: Sealed Bid',
#  'Auction: Turn Order Until Pass',
#  'Automatic Resource Growth',
#  'Betting and Bluffing',
#  'Bias',
#  'Bingo',
#  'Bribery',
#  'Campaign / Battle Card Driven',
#  'Card Play Conflict Resolution',
#  'Catch the Leader',
#  'Chaining',
#  'Closed Drafting',
#  'Closed Economy Auction',
#  'Command Cards',
#  'Commodity Speculation',
#  'Communication Limits',
#  'Connections',
#  'Constrained Bidding',
#  'Contracts',
#  'Cooperative Game',
#  'Critical Hits and Failures',
#  'Cube Tower',
#  'Deck Construction',
#  'Deck, Bag, and Pool Building',
#  'Deduction',
#  'Delayed Purchase',
#  'Dice Rolling',
#  'Die Icon Resolution',
#  'Different Dice Movement',
#  'Elapsed Real Time Ending',
#  'Enclosure',
#  'End Game Bonuses',
#  'Events',
#  'Finale Ending',
#  'Flicking',
#  'Follow',
#  'Force Commitment',
#  'Grid Coverage',
#  'Grid Movement',
#  'Hand Management',
#  'Hexagon Grid',
#  'Hidden Movement',
#  'Hidden Roles',
#  'Hidden Victory Points',
#  'Highest-Lowest Scoring',
#  'I Cut, You Choose',
#  'Income',
#  'Increase Value of Unchosen Resources',
#  'Induction',
#  'Interrupts',
#  'Investment',
#  'Kill Steal',
#  'King of the Hill',
#  'Ladder Climbing',
#  'Layering',
#  'Legacy Game',
#  'Line Drawing',
#  'Line of Sight',
#  'Loans',
#  'Lose a Turn',
#  'Mancala',
#  'Map Addition',
#  'Map Deformation',
#  'Map Reduction',
#  'Market',
#  'Measurement Movement',
#  'Melding and Splaying',
#  'Memory',
#  'Minimap Resolution',
#  'Modular Board',
#  'Move Through Deck',
#  'Movement Points',
#  'Movement Template',
#  'Moving Multiple Units',
#  'Multiple Maps',
#  'Multiple-Lot Auction',
#  'Narrative Choice / Paragraph',
#  'Negotiation',
#  'Network and Route Building',
#  'Once-Per-Game Abilities',
#  'Open Drafting',
#  'Order Counters',
#  'Ownership',
#  'Paper-and-Pencil',
#  'Passed Action Token',
#  'Pattern Building',
#  'Pattern Movement',
#  'Pattern Recognition',
#  'Physical Removal',
#  'Pick-up and Deliver',
#  'Pieces as Map',
#  'Player Elimination',
#  'Point to Point Movement',
#  'Predictive Bid',
#  "Prisoner's Dilemma",
#  'Programmed Movement',
#  'Push Your Luck',
#  'Race',
#  'Random Production',
#  'Ratio / Combat Results Table',
#  'Re-rolling and Locking',
#  'Real-Time',
#  'Relative Movement',
#  'Resource to Move',
#  'Rock-Paper-Scissors',
#  'Role Playing',
#  'Roles with Asymmetric Information',
#  'Roll / Spin and Move',
#  'Rondel',
#  'Scenario / Mission / Campaign Game',
#  'Score-and-Reset Game',
#  'Secret Unit Deployment',
#  'Selection Order Bid',
#  'Semi-Cooperative Game',
#  'Set Collection',
#  'Simulation',
#  'Simultaneous Action Selection',
#  'Singing',
#  'Single Loser Game',
#  'Slide/Push',
#  'Solo / Solitaire Game',
#  'Square Grid',
#  'Stacking and Balancing',
#  'Stat Check Resolution',
#  'Static Capture',
#  'Stock Holding',
#  'Storytelling',
#  'Sudden Death Ending',
#  'Take That',
#  'Targeted Clues',
#  'Team-Based Game',
#  'Tech Trees / Tech Tracks',
#  'Three Dimensional Movement',
#  'Tile Placement',
#  'Time Track',
#  'Track Movement',
#  'Trading',
#  'Traitor Game',
#  'Trick-taking',
#  'Tug of War',
#  'Turn Order: Auction',
#  'Turn Order: Claim Action',
#  'Turn Order: Pass Order',
#  'Turn Order: Progressive',
#  'Turn Order: Random',
#  'Turn Order: Role Order',
#  'Turn Order: Stat-Based',
#  'Variable Phase Order',
#  'Variable Player Powers',
#  'Variable Set-up',
#  'Victory Points as a Resource',
#  'Voting',
#  'Worker Placement',
#  'Worker Placement with Dice Workers',
#  'Worker Placement, Different Worker Types',
#  'Zone of Control'}

# %%
designers = []
for row in recom['designers']:
    designers += row.split('|')
set(designers)
# Out:
# {'(Uncredited)',
#  'Aaron Dill',
#  'Aaron Weissblum',
#  'Acchittocca',
#  'Adam Carlson',
#  'Adam Kałuża',
#  'Adam Kwapiński',
#  'Adam P. McIver',
#  'Adam Poots',
#  'Adam Rebottaro',
#  'Adam Sadler',
#  'Adam Spanel',
#  'Adrian Abela',
#  'Adrian Adamescu',
#  'Akihisa Okui',
#  'Alain Orban',
#  'Alain Rivollet',
#  'Alan Gerding',
#  'Alan R. Moon',
#  'Alan Roach',
#  'Alan Stone',
#  'Alban Viard',
#  'Alex Davy',
#  'Alex Hague',
#  'Alex Randolph',
#  'Alex Rockwell',
#  'Alexandar Ortloff',
#  'Alexander Pfister',
#  'Alexander Schmidt (II)',
#  'Alexandr Ushan',
#  'Allan B. Calhamer',
#  'Alvydas Jakeliunas',
#  'Amabel Holland',
#  'Ananda Gupta',
#  'Andrea Chiarvesio',
#  'Andrea Crespi',
#  'Andreas "ode." Odendahl',
#  'Andreas Pelikan',
#  'Andreas Schmidt',
#  'Andreas Seyfarth',
#  'Andreas Steding',
#  'Andreas Steiger',
#  'Andrew Looney',
#  'Andrew Nerger',
#  'Andrew Parks',
#  'Andrew Ruhnke',
#  'Andrew Veen',
#  'Andrew Wolf',
#  'André Zatz',
#  'Andy Clautice',
#  'Andy Hoare',
#  'Andy Jones',
#  'Annick Lobet',
#  'Anthony J. Gallela',
#  'Antoine Bauza',
#  'Antonio Tinto',
#  'Aristide Bruyant',
#  'Aron West',
#  'Asger Harding Granerud',
#  'BakaFire',
#  'Beau Beckett',
#  'Ben Cichoski',
#  'Ben Eisner',
#  'Ben Goldman',
#  'Ben Pinchback',
#  'Ben Rosset',
#  'Ben Stoll',
#  'Benjamin Pope',
#  'Benjamin Schwer',
#  'Benoit Turpin',
#  'Benoit Vogt',
#  'Bernard Tavitian',
#  'Bernd Brunnhofer',
#  'Bill Eberle',
#  'Bill McQuillan',
#  'Bill Norton',
#  'Bill Slavicsek',
#  'Bobby Hill',
#  'Bowen Simmons',
#  'Brad Andres',
#  'Brad Johnson (I)',
#  'Brady Sadler',
#  'Brandon Tibbetts',
#  'Brenna Moncur',
#  'Brent Beck',
#  'Brent Dickman',
#  'Brent Keith',
#  'Brent Povis',
#  'Brett J. Gilbert',
#  'Brett Sobol',
#  'Brian Gomez',
#  'Brian Lewis',
#  'Brian M. Kibler',
#  'Brian Mayer',
#  'Brian Neff',
#  "Brian O'Neill",
#  'Brian Train',
#  'Brian Yu',
#  'Brooklynn Lundberg',
#  'Bruce Allen',
#  'Bruce Glassco',
#  'Bruno Cathala',
#  'Bruno Faidutti',
#  'Bruno Sautter',
#  'Bryan Kinsella',
#  'Bryan Pope',
#  'Bryan Reese',
#  'Caleb Grace',
#  'Carey Grayson',
#  'Carl Chudyk',
#  'Carl Paradis',
#  'Carl de Visser',
#  'Carla Horger',
#  'Carsten Lauber',
#  'Chad Brown',
#  'Chad Jensen',
#  'Charles Chevallier',
#  'Charlie Catino',
#  'Chris Cantrell',
#  'Chris Cieslik',
#  'Chris Darsaklis',
#  'Chris Dupuis',
#  'Chris Leder',
#  'Chris Nelson',
#  'Chris Taylor (I)',
#  'Christian Leonhard',
#  'Christian Marcussen',
#  'Christian Martinez',
#  'Christian T. Petersen',
#  'Christophe Boelinger',
#  'Christophe Raimbault',
#  'Christopher Badell',
#  'Christopher Chung',
#  "Christopher O'Neal",
#  'Chuck D. Yager',
#  'Claudia Hely',
#  'Claudia Partenheimer',
#  'Clayton Helme',
#  'Cody Miller',
#  'Colby Dauch',
#  'Cole Wehrle',
#  'Connor Reid',
#  'Corentin Lebrat',
#  'Corey Konieczka',
#  'Corné van Moorsel',
#  'Courtney F. Allen',
#  'Craig Besinque',
#  'Craig Van Ness',
#  'Croc',
#  'Cyril Demaegd',
#  'Cédric Lefebvre',
#  'Cédric Millet',
#  'Cédrick Chaboussit',
#  'D. Brad Talton, Jr.',
#  'Dan Blanchett',
#  'Dan Cassar',
#  'Dan Hallagan',
#  'Dane Beltrami',
#  'Daniel Clark (I)',
#  'Daniel Mandel',
#  'Daniel Piechnick',
#  'Daniel Skjold Pedersen',
#  'Daniele Tascini',
#  'Danny Devine',
#  'Darrell Hardy',
#  'Darwin Kastle',
#  'Daryl Andrews',
#  'Dave Kimmel',
#  'Dave Neale',
#  'David Chircop',
#  'David Cicurel',
#  'David Franck',
#  'David Sanders',
#  'David Short',
#  'David Somerville',
#  'David Thompson (I)',
#  'Dennis K. Chan',
#  'Devin Low',
#  'Dirk Henn',
#  'Dmitry Knorre',
#  'Dominic Crapuchettes',
#  'Dominique Bodin',
#  'Dominique Ehrhard',
#  'Don Eskridge',
#  'Don Greenwood',
#  'Donald X. Vaccarino',
#  'Doug Eckhart',
#  'Duccio Vitale',
#  'Dávid Turczi',
#  'Ed Beach',
#  'Ed Carter',
#  'Ed Marriott',
#  'Eduardo Baraf',
#  'Edward Bolme',
#  'Eilif Svensson',
#  'Einar Rosén',
#  'Elizabeth Hargrave',
#  'Elwen',
#  'Emerson Matsuuchi',
#  'Eric Goldberg',
#  'Eric Lee Smith',
#  'Eric M. Lang',
#  'Eric Randall',
#  'Eric Zimmerman',
#  'Ethan Pasternack',
#  'Etienne Espreman',
#  'Evan Derrick',
#  'Fabien Riffaud',
#  'Fabio Lopiano',
#  'Fabrice Rabellino',
#  'Federico Pierlorenzi',
#  'Filip Miłuński',
#  'Filip Neduk',
#  'Flaminia Brasini',
#  'Forrest-Pruzan Creative',
#  'Fran Diaz',
#  'Francesco Nepitello',
#  'Francesco Testini',
#  'Francis Tresham',
#  'Frank Brooks',
#  'Frank West',
#  'Franz-Benno Delonge',
#  'François Gandon',
#  'Fraser Lamont',
#  'Fred Perret',
#  'Friedemann Friese',
#  'Frédéric Guérard',
#  'Frédéric Henry',
#  'Gabriele Mari',
#  'Gaby Weidling',
#  'Galen Ciscell',
#  'Gary Arant',
#  'Gary Dicken',
#  'Gary Grady',
#  'Gary Kim',
#  'Gavan Brown',
#  'Gavin Birnbaum',
#  'Gaëtan Beaujannot',
#  'Gerd Fenchel',
#  'Ghislain Masson',
#  'Gianluca Santopietro',
#  'Gil Hova',
#  "Gil d'Orey",
#  'Glenn Drover',
#  'Gord!',
#  'Gordon Lamont',
#  'Goro Sasaki',
#  'Grace Holdinghaus',
#  'Graeme Jahns',
#  'Grant Rodiek',
#  'Greg Daigle',
#  'Gregory Marques',
#  'Grégory Oliver',
#  'Guilherme Goulart',
#  'Guillaume Montiage',
#  'Günter Cornett',
#  'Haakon Gaarder',
#  'Hal Duncan',
#  'Harold Vanderbilt',
#  'Helge Ostertag',
#  'Helmut Ohley',
#  'Henry Audubon',
#  'Henry Stern',
#  'Hermann Luttmann',
#  'Hervé Lemaître',
#  'Hervé Marly',
#  'Hervé Rigal',
#  'Hisashi Hayashi',
#  'Hjalmar Hach',
#  'Hoby Chou',
#  'Ian Brody',
#  'Ian Estrin',
#  'Ian Tate',
#  'Ignacy Trzewiczek',
#  'Inka Brand',
#  'Isaac Childres',
#  'Isaac Vega',
#  'Isaias Vallejo',
#  'Isra C.',
#  'Ivan Lashin',
#  'Ivan Tuzovsky',
#  'J. Alex Kevern',
#  'J. Arthur Ellis',
#  'J.B. Howell',
#  'JR Honeycutt',
#  'Jack Kittredge',
#  'Jacob Fryxelius',
#  'Jacques Bariot',
#  'Jacques Zeimet',
#  'Jakub Wiśniewski',
#  'Jakub Łapot',
#  'James A. Wilson',
#  'James Ernest',
#  'James Kniffen',
#  'James M. Hewitt',
#  'Jamey Stegmaier',
#  'Jan Soukal',
#  'Jaro Andruszkiewicz',
#  'Jarratt Gray',
#  'Jason C. Hill',
#  'Jason Little',
#  'Jason Matthews',
#  'Jay Cormier',
#  'Jay Schneider',
#  'Jean Yves Monpertuis',
#  'Jean du Poël',
#  'Jean-Baptiste Lullien',
#  'Jean-Louis Roubira',
#  'Jeff Beck (II)',
#  'Jeff Chin',
#  'Jeff Grossman',
#  'Jeff Horger',
#  'Jeff Liu',
#  'Jeffrey Beck',
#  'Jens Christopher Ulrich',
#  'Jens Drögemüller',
#  'Jeph Stahl',
#  'Jeremy Holcomb',
#  'Jeremy Stoltzfus',
#  'Jeroen Doumen',
#  'Jerry Hawthorne',
#  'Jerry Taylor',
#  'Jervis Johnson',
#  'Jesús Torres Castro',
#  'Jim Gutt',
#  'Jim Krohn',
#  'Jim Lin',
#  'Joanna Kijanka',
#  'Joel Finch',
#  'Johannes Sich',
#  'John Bohrer',
#  'John D. Clair',
#  'John Fiorillo',
#  'John Foley',
#  'John Goodenough',
#  'John H. Butterfield',
#  'John Hill (I)',
#  'John Kean',
#  'John Kovaleski',
#  'John Yianni',
#  'John Zinser',
#  "Johnny O'Neal",
#  'Jon Mietling',
#  'Jon Perry',
#  'Jonathan Gilmour',
#  'Jonathan Ying',
#  'Jordy Adan',
#  'Joris Wiersinga',
#  'Jose Antonio Abascal Acebo',
#  'Joseph Fatula',
#  'Joseph Z Chen',
#  'Josh J. Carlson',
#  'Josh Wielgus',
#  'Josh Wood',
#  'Joshua Buergel',
#  'Juan Rodriguez',
#  'Julian Courtland-Smith',
#  'Juma Al-JouJou',
#  'Jun Sasaki',
#  'Justin Blaske',
#  'Justin D. Jacobson',
#  'Justin Faulkner',
#  'Justin Gary',
#  'Justin Kemppainen',
#  'Justin Vickers',
#  'Jérôme Ropert',
#  'Kai Jensen',
#  'Kalle Malmioja',
#  'Kami Mandell',
#  'Kane Klenko',
#  'Kara Centell-Dunk',
#  'Karen Seyfarth',
#  'Karl-Heinz Schmiel',
#  'Karsten Hartwig',
#  'Kasper Aagaard',
#  'Kasper Lapp',
#  'Keith Matejka',
#  'Ken Dunn',
#  'Ken Fisher',
#  'Kenneth Minde',
#  'Kevin Bishop',
#  'Kevin Lanzing',
#  'Kevin Maroney',
#  'Kevin Nesbitt',
#  'Kevin Riley',
#  'Kevin Rodgers',
#  'Kevin Russ',
#  'Kevin Wilson',
#  'Klaus Miltenberger',
#  'Klaus Teuber',
#  'Klaus Zoch',
#  'Klaus-Jürgen Wrede',
#  'Klemens Kalicki',
#  'Konstantinos Kokkinis',
#  'Koota Yamada',
#  'Kory Heath',
#  'Kota Nakayama (中山 宏太)',
#  'Kris Burm',
#  'Kristian Amundsen Østby',
#  'Krzysztof Piskorski',
#  'Larry Harris, Jr.',
#  'Laurent Escoffier',
#  'Laurent Lavaur',
#  'Laurent Pouchain',
#  'Leonhard "Lonny" Orgler',
#  'Lewis Pulsipher',
#  'Lincoln Petersen',
#  'Lorenzo Silva',
#  'Louis Malz',
#  'Luca Iennaco',
#  'Luca Ricci',
#  'Ludovic Maublanc',
#  'Ludovic Roudy',
#  'Lukas Litzsinger',
#  'Lukas Zach',
#  'Luke Laurie',
#  'MJ Newman',
#  'Mac Gerdts',
#  'Malcolm Braff',
#  'Manny Trembley',
#  'Manuel Rozoy',
#  'Marc André',
#  'Marc Kelsey',
#  'Marc Neidlinger',
#  'Marc Paquien',
#  'Marcel Süßelbeck',
#  'Marcel-André Casasola Merkle',
#  'Marcin Świerkot',
#  'Marco Canetta',
#  'Marco Maggi',
#  'Marco Montanaro',
#  'Marco Portugal',
#  'Marco Ruskowski',
#  'Mark Herman',
#  'Mark K. Swanson',
#  'Mark Major',
#  'Mark Simonitch',
#  'Mark Tuck',
#  'Mark Wootton',
#  'Markus Brand',
#  'Markus Lübke',
#  'Martin Wallace',
#  'Masato Uesugi',
#  'Mathias Wigge',
#  'Mathieu Casnin',
#  'Matt Calkins',
#  'Matt Eklund',
#  'Matt Hyra',
#  'Matt Leacock',
#  'Matt Riddle',
#  'Matt Tolman',
#  'Matthew Dunstan',
#  "Matthew O'Malley",
#  'Matthias Cramer',
#  'Matúš Kotry',
#  'Max Temkin',
#  'Maxime Rambourg',
#  'Michael Adams',
#  'Michael Boggs',
#  'Michael Gray',
#  'Michael Keller (II)',
#  'Michael Kiesling',
#  'Michael Menzel',
#  'Michael Palm',
#  'Michael Rieneck',
#  'Michael Schacht',
#  'Michael Shinall',
#  'Michal Mikeš',
#  'Michał Gołębiowski',
#  'Michał Oracz',
#  'Michał Walczak',
#  'Michiel Justin Elliott Hendriks',
#  'Mike Boxleiter',
#  'Mike Elliott',
#  'Mike Fitzgerald',
#  'Mike Mearls',
#  'Mike Nudd',
#  'Mike Selinker',
#  'Mikkel Bertelsen',
#  'Molly Glover',
#  'Molly Johnson',
#  'Mr. Bistro',
#  'Mín',
#  'Naoki Homma',
#  'Nate Chatellier',
#  'Nate French',
#  'Nathan I. Hajek',
#  'Nathan Tiras',
#  'Nestore Mangone',
#  'Nick Bentley',
#  'Nick Little (I)',
#  'Nicolas Raoult',
#  'Nicolas Robert',
#  'Nigel Buckle',
#  'Nikki Valens',
#  'Nina Håkansson',
#  'Noah Cohen',
#  'Nuno Bizarro Sentieiro',
#  'Nunzio Surace',
#  'Ole Steiness',
#  'Oleg Sidorenko',
#  'Oleksandr Nevskiy',
#  'Oliver Richtberg',
#  'Ondra Skoupý',
#  'Orin Bishop',
#  'Paolo Mori',
#  'Pascal Bernard',
#  'Patrick Leder',
#  'Patrick Rothfuss',
#  'Paul Bender',
#  'Paul Dennen',
#  'Paul Kluka',
#  'Paul Peterson',
#  'Paul Salomon',
#  'Paulo Soledade',
#  'Peer Sylvester',
#  'Peggy Chassenet',
#  'Peter Hawes',
#  'Peter Lee',
#  'Peter McPherson',
#  'Peter Olotka',
#  'Peter Prinz',
#  'Peter Rustemeyer',
#  'Peter Sarrett',
#  'Peter Wichmann',
#  'Phil Eklund',
#  'Phil Kendall',
#  'Phil Walker-Harding',
#  'Philip duBarry',
#  'Philippe Keyaerts',
#  'Pierluca Zizzi',
#  'Piotr Haraszczak',
#  'Prashant Saraswat',
#  'Prospero Hall',
#  'Przemysław Rymer',
#  'R. Eric Reuss',
#  'Ralf Partenheimer',
#  'Ralf zur Linde',
#  'Randy Flynn',
#  'Randy Nash',
#  'Raphaël Guiton',
#  'Raymond Chandler III',
#  'Raymond Edwards',
#  'Reiner Knizia',
#  'Reiner Stockhausen',
#  'Richard Amann',
#  'Richard Berthold',
#  'Richard Borg',
#  'Richard Breese',
#  'Richard Garfield',
#  'Richard Halliwell',
#  'Richard Hamblen',
#  'Richard Keene',
#  'Richard Launius',
#  'Richard Sivél',
#  'Richard Ulrich',
#  'Rick Ernst',
#  'Rick Soued',
#  'Rikki Tahta',
#  'Rob Daviau',
#  'Rob Heinsoo',
#  'Rob Watkins (Board Game) (I)',
#  'Robert A. Kouba',
#  'Robert Dougherty',
#  'Robert Haines',
#  'Robert Melvin',
#  'Robert Rosén',
#  'Roberto Di Meglio',
#  'Roberto Fraga',
#  'Rodney Thompson',
#  'Roman Pelek',
#  'Ron Gonzalo García',
#  'Rustan Håkansson',
#  'Ruth Veevers',
#  'Ryan Amos',
#  'Ryan Courtney',
#  'Ryan Laukat',
#  'Ryan Miller',
#  "Ryan O'Connor",
#  'Régis Bonnessée',
#  'Rüdiger Dorn',
#  'S J Macdonald',
#  'Saashi',
#  'Sami Laakso',
#  'Samuel Bailey',
#  'Sandy Petersen',
#  'Scot Eaton',
#  'Scott Almes',
#  'Scott Caputo',
#  'Scott Frisco',
#  'Sean McCarthy',
#  'Sean McCoy',
#  'Sean Sweigart',
#  'Sebastian Bleasdale',
#  'Seiji Kanai',
#  'Sen-Foong Lim',
#  'Serge Laget',
#  'Sergey Machin',
#  'Seth Jaffee',
#  'Seth Van Orden',
#  'Shadi Torbey',
#  'Shawn Stankewich',
#  'Shei S.',
#  'Shem Phillips',
#  'Shimpei Sato',
#  'Sid Sackson',
#  'Simone Luciani',
#  'Simone Romano',
#  'Sir John Suckling',
#  'Sotirios Tsantilas',
#  'Stan Kordonskiy',
#  'Stefan Dorra',
#  'Stefan Feld',
#  'Stefan Malz',
#  'Stefan Risthaus',
#  'Stefan Stadler',
#  'Stefania Niccolini',
#  'Stefano Castelli',
#  'Stefano Luperto',
#  'Steffen Benndorf',
#  'Steffen Bogen',
#  'Stephanie Straw',
#  'Stephen Baker',
#  'Stephen Hand',
#  'Stephen McLaughlin',
#  'Steve Finn',
#  'Steve Kendall',
#  'Steven Aramini',
#  'Steven Kimball',
#  'Steven Strumpf',
#  'Stone Librande',
#  'Susan McKinley Ross',
#  'Suzanne Goldberg',
#  'Sydney Engelstein',
#  'Sébastien Dujardin',
#  'Sébastien Pauchon',
#  'Sérgio Halaban',
#  "Tanis O'Connor",
#  'TauCeti Deichmann',
#  'Ted Alspach',
#  'Ted Raicer',
#  'Ted Torgerson',
#  'Teeuwynn Woodruff',
#  'Thiago Aranha',
#  'Thomas Cauët',
#  'Thomas Dagenais-Lespérance',
#  'Thomas Ewert',
#  'Thomas Lehmann',
#  'Thomas Sing',
#  'Thomas Vande Ginste',
#  'Thorsten Gimmler',
#  'Théo Rivière',
#  'Tim Eisner',
#  'Tim Fowers',
#  'Tim Pinder',
#  'Tim Puls',
#  'Tim Uren',
#  'Tobey Ho',
#  'Todd Michlitsch',
#  'Tom Cleaver',
#  'Tom Dalgliesh',
#  'Tom Jolly',
#  'Tom McMurchie',
#  'Tommaso Battista',
#  'Tommy Maranges',
#  'Tomáš Uhlíř',
#  'Tony Boydell',
#  'Tony Fanchi',
#  'Tony Go',
#  'Tory Niemann',
#  'Touko Tahkokallio',
#  'Trevor Benjamin',
#  'Trey Chambers',
#  'Urs Hostettler',
#  'Uwe Eickert',
#  'Uwe Rosenberg',
#  'Vangelis Bagiartakis',
#  'Vienna Chou',
#  'Viktor Peter',
#  'Vincent Goyat',
#  'Virginio Gigli',
#  'Vital Lacerda',
#  'Vlaada Chvátil',
#  'Vladimír Suchý',
#  'Volko Ruhnke',
#  'Walter Schneider',
#  'Wei-Hwa Huang',
#  'William Attia',
#  'Wojciech Grajkowski',
#  'Wolf Plancke',
#  'Wolfgang Kramer',
#  'Wolfgang Panning',
#  'Wolfgang Sentker',
#  'Wolfgang Warsch',
#  'Wray Ferrell',
#  'Xavier Georges',
#  'Yasutaka Ikeda',
#  'Yoann Levet',
#  'Yohan Lemonnier',
#  'Yohan Servais',
#  'Zev Shlasinger'}

# %%
publishers = []
for row in recom['publishers']:
    publishers += row.split('|')
set(publishers)
# Out:
# {'Play All Day Games',
#  'Horrible Guild',
#  'Cheapass Games',
#  'MB Spiele',
#  'Edition Spielwiese',
#  'EVA GAMES',
#  'Vilac',
#  'Descartes Editeur',
#  'Side Room Games',
#  'Gamewright',
#  'Neroulia',
#  'Phalanx Games Deutschland',
#  "OPEN'N PLAY",
#  'Cogitate Games',
#  'Meanbook Games',
#  'Giga Mech Games',
#  'HEMA',
#  'Stratelibri',
#  'Ogry Games',
#  'TRY SOFT',
#  'Last Level',
#  'Portal Games',
#  'Wood Expressions',
#  'Ludically',
#  'Dilemma Games',
#  'Cayro, the games',
#  'Grok Games',
#  'Goat Wolf & Cabbage',
#  'Montrose Games LLC',
#  'Hodin',
#  'Big Fun Games (Board Game)',
#  'Hexagames (I)',
#  'Repos Production',
#  'Golden Spike Games',
#  'Oink Games',
#  'Drawlab Entertainment',
#  'Ludens Planet',
#  'GaGa Games',
#  'Big Potato',
#  'Academy Games, Inc.',
#  'Gameland 游戏大陆',
#  'Coiledspring Games',
#  'The Mark of Westminster',
#  '数寄ゲームズ (Suki Games)',
#  'Pretzel Games',
#  'JKLM Games',
#  'Tropical Games',
#  'Feelindigo',
#  'UBO CnC',
#  'Asmodee',
#  'Intercontor AG',
#  'Igiari',
#  'Patch Products',
#  'Waddington Sanders Ltd.',
#  'GameWorks SàRL',
#  'Red Glove',
#  'Ludonova',
#  'Fabled Nexus',
#  '2F-Spiele',
#  'Looney Labs',
#  'Sleuth Publications',
#  'FoxMind Israel',
#  'Ventura Games',
#  'Rightgames RBG SIA',
#  'House of Marbles',
#  'Nash Games',
#  'The Game Master BV',
#  'Blue Cocker Games',
#  'Far Off Games',
#  'Holdson',
#  'Spin Master Ltd.',
#  'Kingsway Inc',
#  'Ishi Press International',
#  'Noris Spiele',
#  'Cambridge Games Factory',
#  'Challenge Master Game Co Ltd',
#  'Cuaca Cerah Games',
#  'Guf Studios',
#  'Feuerland Spiele',
#  'BrownCastle Games',
#  'Playgo Hungary',
#  'Dice Hate Me Studio',
#  'Curiosity Games',
#  'TAG',
#  'Milton Bradley',
#  'AMIGO',
#  'Golconda',
#  'Ares Games',
#  'Czacha Games',
#  'Switch Games',
#  'TIKI Editions',
#  'Monkey Time',
#  'Paper Iyagi',
#  'Goliath Games',
#  'Galakta',
#  'National Mah Jongg League, Inc.',
#  'Lanlalen',
#  'Oficina do Aprendiz',
#  'Mattel, Inc.',
#  'Gen42 Games',
#  'MindWare',
#  'Egmont Polska',
#  'Dujardin',
#  'Wiley Publishing, Inc.',
#  'Comedy Partners',
#  'AVStudioGames',
#  'Tactic',
#  'Lotus Frog Games',
#  'Filosofia Éditions',
#  'Fever Games',
#  '株式会社ケンビル (KenBill)',
#  'E.S. Lowe',
#  'Ludus Magnus Studio',
#  'Common Man Games',
#  'MTS Games',
#  'Yellowstar Games',
#  'University Games',
#  'Redbox Editora (Redbox)',
#  'Hausemann & Hötte N.V.',
#  'Emperor Penguin Games',
#  'Guigou',
#  'Flick Game Studio',
#  'cosaic',
#  'Jolly Thinkers',
#  'Schwerkraft-Verlag',
#  'Plaid Hat Games',
#  'Hartung-Spiele',
#  'ChessUSA',
#  'Fantasy Shop',
#  'One Moment Games',
#  'M-Ágnes',
#  'Geek Attitude Games',
#  'Buró',
#  'Keep Exploring Games',
#  "Kellogg's",
#  'Abi Games',
#  'James Ernest Games',
#  'SPM: Syarikat Permainan Malaysia',
#  'Ísöld ehf.',
#  'Rot Ceramic',
#  'Western Publishing Company',
#  'Ludofy Creative',
#  'Awaken Realms',
#  'Kanga Games',
#  'Hobby Base',
#  'Foxtrot Games',
#  'Chessex',
#  'Sherlock S.A.',
#  'Spaghetti Western Games',
#  'U3',
#  'Copag Cards',
#  'Ludicus',
#  'Mitra',
#  'Character Games LTD',
#  'BLAM !',
#  'FryxGames',
#  'Zacatrus',
#  'Kikigagne?',
#  'Mar Lúdico',
#  'Hobby World',
#  'Warfrog Games',
#  'KDS Distribuzione',
#  'PopcornEdu',
#  'Maldito Games',
#  'Hanayama',
#  'Sato Kei Shoten Co., Ltd.',
#  'Truant Spiele',
#  'BoardBros',
#  'Hachette Board Games UK',
#  'Red Raven Games',
#  'Button Shy',
#  'Eurogames',
#  '5th Peg',
#  'Palitoy Ltd.',
#  'Mayday Games',
#  'ASYNCRON games',
#  'Kitfix Swallow Group',
#  'Mancalamaro',
#  'Schmidt France',
#  'ElfinWerks',
#  'Czech Board Games',
#  'Felsberger',
#  'VR Distribution',
#  'Morapiaf',
#  'Pegasus Spiele',
#  'Gen-X Games',
#  'Heyne',
#  'ADC Blackfire Entertainment GmbH',
#  'Italocremona',
#  'Djama Games',
#  'Pressman Toy Corp.',
#  'Pixie Games',
#  'innovative KIDS',
#  'Guillotine Games',
#  'Inside the Box Board Games LLP (ITB)',
#  'Wydawnictwo Gołębiewski',
#  'Devil Dice Games',
#  'David Westnedge',
#  'Choo Choo Games',
#  'DreamWorks',
#  'U.S. Games Systems, Inc.',
#  'Competo / Marektoy',
#  'Handfaste',
#  'Olsen',
#  'Sovranti',
#  'Corfix',
#  'Estrela',
#  'The City of Games',
#  'HomoLudicus',
#  'Abraxas',
#  'Gameology (Gameology Romania)',
#  'Ultra PRO',
#  '2K Games, Inc.',
#  'MS Edizioni',
#  'Keymaster Games',
#  'Excalibur (Board Game)',
#  'Corax Games',
#  'Dino Toys s. r. o.',
#  'Dourios',
#  'Smart Zone Games',
#  'Cosmodrome Games',
#  'El Greco',
#  'Tantrix UK Ltd.',
#  'Tau Leader Games',
#  'Big League Promotions Corp.',
#  'Divercentro',
#  'Tesla Games',
#  'Borras Plana S.A.',
#  'Mind Bottling Games',
#  'uplay.it edizioni',
#  'Gém Klub Kft.',
#  'Lookout Games',
#  'General Sportcraft Company',
#  'Funtails',
#  'Shafir Games (המשחקים של חיים שפיר)',
#  'Are-Jay Game Company',
#  'Rebel Sp. z o.o.',
#  'Toy Box Games',
#  "O'Gowna Studio",
#  'Super Meeple',
#  'Thunderworks Games',
#  'W. D. & H. O. Wills',
#  'Alley Cat Games',
#  'Mondo Games',
#  'Pridemage Games',
#  'Boat City',
#  'The Game Crafter, LLC',
#  'Yayoi The Dreamer',
#  'Cappelen',
#  'Firaxis Games, Inc.',
#  'Dire Wolf',
#  'minimalGames',
#  'Panda Game Manufacturing (PandaGM)',
#  'F2Z Digital Media Inc.',
#  'Sekkoia',
#  'Games 4 Gamers',
#  'Pandasaurus Games',
#  'Litor',
#  'Beverly Enterprises, Inc.',
#  'Swan Panasia Co., Ltd.',
#  'House Martin',
#  'Fun Consortium',
#  'Sit Down!',
#  'Elf Creek Games',
#  'ASS Altenburger Spielkarten',
#  'funbot',
#  'Lucky 6ix',
#  'The Op',
#  'TCG Factory',
#  'Pendragon Game Studio',
#  'Craftando Jogos',
#  'Fame Products',
#  'ABACUSSPIELE',
#  'Westside Fun Games',
#  'Geekach Games',
#  'Peri Spiele',
#  'Roomiz Games',
#  'Megacorpin Games',
#  'Portal Dragon',
#  'Fox in the Box',
#  'WizKids (I)',
#  'Nauvoo Games',
#  'Hexasim',
#  'Paul Lamond Games Ltd',
#  'C.R. Gibson',
#  'Ion Game Design',
#  'GDM Games',
#  'Imagine Jogos',
#  'Delirium Games',
#  'Alexander',
#  'NewGame',
#  'sternenschimmermeer',
#  'Skellig Games',
#  "Surfin' Meeple",
#  'Das Spiel',
#  'Kod Kod',
#  'Inter Hobby Co., Ltd.',
#  'Überplay',
#  'El Dragón Azul',
#  'Parker Spiele',
#  'The Bored Game Company',
#  'Passport Game Studios',
#  'Imaginarium',
#  'Victory Games (I)',
#  'Bar-Zim',
#  'Sunnygeeks',
#  'Peliko',
#  'Funiverse',
#  'Happy meeple games',
#  'The Avalon Hill Game Co',
#  'L4 Studios',
#  'BGA Plus',
#  'Reiss Games',
#  'Looping Games',
#  'Green Eye Games',
#  'eggertspiele',
#  'Fun Supply',
#  'Angry Lion Games',
#  'Parker Brothers',
#  "Berwick's Toy Co. Ltd.",
#  'Japon Brand',
#  'Face2Face Games',
#  'Druid City Games',
#  'Level 99 Games',
#  'kártyagyár',
#  'Kärnan',
#  'Nu-Bef',
#  'Group SNE',
#  'Petersen Games',
#  'Lex Games',
#  'MEEPLE',
#  'Enjoy Game',
#  'Columbia Games',
#  'Argentum Verlag',
#  'Pavilion',
#  'Venice Connection',
#  'Sophisticated Games',
#  'Happy Baobab',
#  'Taverna Ludica Games',
#  'Fabrika Igr',
#  'Compendium Games',
#  'Guanhua (冠華)',
#  'Dynamic Games / Dynamic Design Industries',
#  'Game Salute',
#  'Silver Stars Publishing',
#  'Ancient Chess',
#  'ISA',
#  'Sombreros Production',
#  'Man-indo',
#  'Oxygame',
#  'Lion Rampant Imports',
#  'Carl Weible KG',
#  'Ariel Productions Ltd',
#  'Bragelonne Games',
#  'Golden Egg Games',
#  'Fantasiapelit',
#  'Super Accord',
#  'Mercurio',
#  'The Wood Games',
#  'Takara',
#  'Lucky Duck Games',
#  'Cranio Creations',
#  'WoodCat',
#  'Lardy International',
#  'Möbius Games',
#  'Creative Crafthouse',
#  'Quick Simple Fun Games',
#  'Lacerta',
#  'Boardgame Mall',
#  'Bard Centrum Gier',
#  'Popcorn Games',
#  'DICE TOWER ESSENTIALS',
#  'Oriental Trading Company',
#  'Royal Depth',
#  'Asmodee Italia',
#  'North Star Games',
#  'Lui-même',
#  'Yes Papa Games',
#  'Board Game Rookie',
#  'FRED Distribution, Inc.',
#  'Clever Mojo Games',
#  'Board Game Leisure',
#  'Greater Than Games, LLC',
#  'Atalia',
#  'La Boîte de Jeu',
#  'Phantasia Co., Ltd',
#  'Morning',
#  'Lindop (William Lindop LTD)',
#  'Astrel Games',
#  'Games7Days',
#  'Gametrade Distribuzione',
#  'Granna',
#  'KADABRA',
#  'Pearl Games',
#  '11 bit studios',
#  'JK Games',
#  'BGNations',
#  'Runadrake',
#  'Manchester United Football Club',
#  'Funbox Editora',
#  'Merit',
#  'Playbox',
#  'Summon Games',
#  'Tilsit',
#  'Black Book Éditions',
#  'Wooden You Know Crokinole Boards',
#  'Sorry We Are French',
#  'Conclave Editora',
#  'Ammonit Spiele',
#  'Ramsons',
#  'Efko',
#  'International Team',
#  'EnumeroCribbageBoards',
#  'NECA',
#  'Joc Internacional',
#  'Miro Company',
#  'Le Scorpion Masqué',
#  'Deuce',
#  'MoveTheGame Edizioni',
#  'Uhrwerk Verlag',
#  'Egmont Litas',
#  'SchilMil Games, Ltd.',
#  'Odysseia Jogos',
#  'Ideal',
#  'Catan Studio',
#  'Kobold Spieleverlag',
#  'Volume-One Products',
#  'MB spil (Danish)',
#  'Game Harbor',
#  'Arsenal Publishing, Inc.',
#  'Wyrmwood Gaming',
#  'Carrom Company',
#  'Pencil First Games, LLC',
#  'Fifth Avenue Crystal Ltd.',
#  'Rio Grande Games',
#  '3M',
#  'PS-Games',
#  'Brain Star',
#  'Chinese Arts & Crafts',
#  'Majora',
#  'Melissa & Doug',
#  'Educa Korea',
#  'Pravi Junak',
#  'Chronicle Games (Board Game)',
#  'Trefl',
#  'Ludonaute',
#  'Albi Polska',
#  'Eagle-Gryphon Games',
#  'Spiele-Offensive.de',
#  'HaKubia',
#  'Van Ryder Games',
#  'REXhry',
#  'TWOPLUS Games',
#  'Interlude',
#  'Philmar',
#  'Chupa Chups',
#  'Mirakulus',
#  'F. W. Woolworth Company',
#  'Nürnberger-Spielkarten-Verlag',
#  'Crokinole World',
#  'Mondadori Giochi',
#  'Mercury Games',
#  'Playhouse',
#  'Nintendo Co., Ltd.',
#  'Regatul Jocurilor',
#  'Engames',
#  'Sweet Games',
#  'Gamemasters Inc.',
#  'A1 Games',
#  'Zhiyanjia',
#  'Editora New Order',
#  'Golden',
#  'MB Spellen',
#  'Horn',
#  'Days of Wonder',
#  'Historien Spiele Galerie (Historien Spielegalerie)',
#  'Smart Ltd',
#  'Yellow Star',
#  'L&M Games',
#  '(Web published)',
#  'Action Phase Games',
#  'SpinBottle Games',
#  'Gamesinitaly',
#  'Chas Goodall & Sons Ltd',
#  'Rawstone',
#  'K. Fisher Enterprises Ltd.',
#  'Fundex',
#  'Space Cowboys',
#  'Calliope Games',
#  'Klee',
#  'Sand Castle Games',
#  'Excalibur Electronics',
#  'Grow Jogos e Brinquedos',
#  'Midgaard Games',
#  "Grandpa Beck's Games",
#  'Dude Games',
#  'Novelty Corp',
#  'Bright World Games',
#  'Mr. B Games',
#  'Gabinete Lúdico',
#  'Asmodee Spain',
#  'פרש משחקים: Game Knight',
#  'Burnt Island Games',
#  'Éveil & Jeux',
#  'Bombyx',
#  'Nordic Games GmbH',
#  'Igroljub',
#  'DeAgostini',
#  'E L & M Productions',
#  'Pando Games',
#  'Aporta Games',
#  'Hobby Japan',
#  'Alary Games',
#  'Sierra Madre Games',
#  'Strohmann Games',
#  'Zoch Verlag',
#  'Spiel & Kunst',
#  'Upper Deck Entertainment',
#  'Magellan',
#  'Edinorog',
#  'Grand Trunk Games',
#  'Crown & Andrews Ltd.',
#  'Histogame',
#  'Flying Frog Productions',
#  'Bozart Toys',
#  'Ninth Haven Games',
#  'Wise Wizard Games',
#  'Clipper',
#  'Delicious Games',
#  'Cross Circle Games',
#  '999 Games',
#  'K & C Ltd',
#  '2Tomatoes Games',
#  'Skandinavisk  Spil Kompagni',
#  'Adams Brothers & Shardlow Ltd.',
#  'Meeple Virus',
#  'Ediciones de Mente',
#  'H. P. Gibson & Sons',
#  'Chad Valley Co Ltd.',
#  'SD Games',
#  'Boardcubator',
#  'Arcane Wonders',
#  'The Game Keeper, Inc.',
#  'Zontik Games',
#  'Ragnar Brothers',
#  'Gamelyn Games',
#  'Land of Beautiful Mind (سرزمین ذهن زیبا)',
#  'Rocks Games',
#  'Vennerød Forlag AS',
#  'Field Mfg. Co.',
#  "Game's Up",
#  'Starling Games (II)',
#  'Fire on Board Jogos',
#  'Mayfair Games',
#  'M. B. Ross',
#  'Grand Gamers Guild',
#  'WOW! What a World of Entertainment AB',
#  'FoxGames',
#  'Valley Games, Inc.',
#  'Comedy Central',
#  'Klopffleisch',
#  'Robin and Nell Dale',
#  'Carlton Books',
#  'Nazca Games',
#  'Meromorph Games',
#  'John Lewis',
#  'Blue Orange Games',
#  'La Mame Games',
#  'Mandala Jogos',
#  'Lifestyle Boardgames Ltd',
#  'Shin Kwang Baduk',
#  'Queen Games',
#  'Funko Games',
#  'Ankama',
#  "Kipo's",
#  'Odd Bird Games',
#  'Yellow Mountain Imports',
#  'گیمِ پندو (Pendo Games)',
#  'Kaissa Chess & Games',
#  'Cardinal',
#  'CoolPlay',
#  'Bureau de Juegos',
#  'GP Games',
#  'Blackrock Games',
#  'Wonder Forge',
#  'Franz Schmidt',
#  'Reflexshop',
#  'Dal Tenda',
#  '(Unknown)',
#  "Spear's Games",
#  'Broadway Toys LTD',
#  'Waddingtons',
#  'Czech Games Edition',
#  'Gremlin Project',
#  'Giochix.it',
#  'Takamagahara',
#  'Orangutan Games',
#  'Schmidt International',
#  'Salt & Pepper Games',
#  'Metafactory Games',
#  'Daily Magic Games',
#  'Vendetta',
#  'Hemz Universal Games Co. Ltd.',
#  'Oliphante',
#  'Gemenot',
#  'Bambus Spieleverlag',
#  'テンデイズゲームズ(TendaysGames)',
#  'Canada Games',
#  'Raven Distribution',
#  'Si-Si-Spiele',
#  'Asmodee Korea',
#  'Hunter & Cron',
#  'J.P. Raymond Rivarola',
#  'ACE Pelit Oy',
#  'Siam Board Games',
#  'Vision',
#  'Penny Arcade',
#  'PHALANX',
#  'Quality Beast',
#  'Нескучные игры',
#  'Cosmic Games',
#  'Invicta Games',
#  'Dexy Co',
#  'Wm F. Drueke & Sons, Inc.',
#  'Saashi & Saashi',
#  'Tracey Boards',
#  'Winsome Games',
#  'Dal Negro',
#  'Asterion Press',
#  'Garphill Games',
#  'Asmodee China',
#  'Liam Games',
#  'Damm / Egmont',
#  'PSC Games',
#  'Intex Syndicate',
#  'After 5 Games',
#  'Elzra Corp. (Elzra)',
#  'Tuesday Knight Games',
#  'Wicked Vision',
#  'Blake Enterprises',
#  'CHH Games',
#  'Succubus Publishing',
#  'Schmidt Spiele',
#  'PaperGames (III)',
#  'Hobby Game Mall',
#  'Philos',
#  "What's Your Game?",
#  '25th Century Games',
#  'Willard',
#  'MYBG Co., Ltd.',
#  'Nuts! Publishing',
#  'Jumbo',
#  'Sir Chester Cobblepot',
#  'Editions Philibert',
#  'Spielquader',
#  'Top Toys',
#  'Asylum Games (Board Games)',
#  'Zito! Ώρα για παιχνίδι',
#  'Hans im Glück',
#  'Mostafil Games',
#  "Kerry's Mah Jong",
#  'Walt Disney Productions (Disney)',
#  'Oya',
#  'MultiSim',
#  'Productief BV',
#  'Adventureland Games',
#  'John Sands Pty Ltd',
#  'International Games',
#  'Revanche Spelen',
#  'Moskito Spiele',
#  'Ergo Ludo Editions',
#  'Planet Finska',
#  'Laurence King Publishing Ltd',
#  'Grey Fox Games',
#  'Mitsubishi Fuso',
#  'Lagoon Games',
#  'Bézier Games',
#  'Phalanx Games B.V.',
#  'Paladium Games',
#  'Ninive Games',
#  'Poptoy',
#  'CZ Cloud Soft Co. Ltd',
#  'Double Diamond',
#  'Underdog Games (I)',
#  'Gemblo, Inc.',
#  'Mosigra',
#  'KOSMOS',
#  'Tíkallinn',
#  'Deep Water Games',
#  'Minion Games',
#  'Dr. Wood Challenge Centre',
#  'Bluebird Games',
#  'dV Giochi',
#  'Copp Clark Publishing Company',
#  'IELLO',
#  'Longfield Games',
#  'Gordion Games',
#  'à la carte AG',
#  'Playtoy Industries',
#  'KDS Distribuzione (Italy)',
#  'GMT Games',
#  'LocWorks',
#  'Cryptozoic Entertainment',
#  '(Self-Published)',
#  "Muzzies' Country Lane Woodshop",
#  'FunBox Jogos',
#  'YOKA Games',
#  'Blackfire Games',
#  'APE Games',
#  'Nexus Editrice',
#  'Drei Magier Spiele',
#  'Tischlerei Knels & Jeske GmbH',
#  "Dr. Finn's Games",
#  'Open Board Games',
#  'Kirjalito',
#  'Happy Color',
#  'BakaFire Party',
#  'GeGe Co. Ltd.',
#  'Ediciones Primigenio',
#  'Splotter Spellen',
#  'Spilaborg hf.',
#  '二見書房 ( Futami Shobo Publishing Co., Ltd. )',
#  '2 Pionki',
#  'Asobition (アソビション)',
#  '963.com',
#  'Fowers Games',
#  'Hartland Trefoil Ltd.',
#  'CCI India',
#  'The Lumenaris Group, Inc.',
#  'Blizzard Entertainment',
#  'Endless Games (I)',
#  'Søstrene Grene',
#  'Jing Studio',
#  'Klask ApS',
#  'Bello Games New York, Inc.',
#  'Mindclash Games',
#  'Halsall',
#  "Roland's Revenge Games",
#  'Plasto',
#  'Next Move Games',
#  'Alga',
#  'Evrikus',
#  'Road To Infamy Games (R2i Games)',
#  'Masters Games',
#  'Взрослые дети',
#  'Creative Educational Aids Pvt. Ltd.',
#  'Ubik',
#  'MB Giochi',
#  'Stonemaier Games',
#  'Brain Games',
#  'Cathay',
#  'Pin International',
#  'DiceTree Games',
#  'Maldón',
#  'L. P. Septímio',
#  'Desyllas Games',
#  'Brädspel.se',
#  'Korea Boardgames Co., Ltd.',
#  'Buly Games',
#  'Black Sea Games',
#  'Gentosha Education',
#  'Front Porch Classics',
#  'VAKKO',
#  'Vem Pra Mesa Jogos',
#  'Second Gate Games',
#  'KOZAK Games',
#  'Gibsons',
#  'HABA',
#  "L'Impensé Radical",
#  'Gigamic',
#  'Monolith',
#  'Mythic Games',
#  'Sterling Games',
#  'Outset Media',
#  'Funagain',
#  'Playagame Edizioni',
#  'Οδύσσεια',
#  'All In Games',
#  "Surfin' Meeple China",
#  'TLAMA games',
#  'Games Workshop Ltd.',
#  'Acme Ruler Company',
#  'BoardGameTables.com',
#  'Hebsacker Verlag',
#  'Purple Meeple Games',
#  'Z-Man Games',
#  'CMON Global Limited',
#  'Nordic Games ehf',
#  'Surprised Stare Games Ltd',
#  'Neuroludic',
#  'Coca-Cola',
#  'Modiano',
#  'Bisonte',
#  'Magic Store Srl',
#  'Floodgate Games',
#  'Across the Board',
#  'Vagabund',
#  'Piet Hein A/S',
#  'Ghenos Games',
#  'Ystari Games',
#  'Nasza Księgarnia',
#  'HC Distribuzione',
#  'Midnight Jungle',
#  'Giant Roc',
#  'Brybelly',
#  'Bayerwald Spiele',
#  'House of Staunton',
#  'Simmons Games',
#  'Gale Force Nine, LLC',
#  'SuperHeated Neurons',
#  'Grapet',
#  'GameField',
#  'Heidelberger Spieleverlag',
#  'Parallel Games',
#  'Kanai Factory',
#  'Amo Oy',
#  'Ideal Board Games',
#  'Fantasmagoria',
#  'Steve Jackson Games',
#  'Randolph',
#  'EmperorS4',
#  'WorldWise Imports, LLC',
#  'Decision Games (I)',
#  'Winning Moves Games (USA)',
#  'IUVI Games',
#  'Top Licence Games',
#  'Goldsieber Spiele',
#  'Treefrog Games',
#  'Beacon Multimedia S.A.',
#  'Ponva d.o.o.',
#  'Saikorodo',
#  'Бельвіль',
#  'Wyrd Edizioni',
#  'R&D Games',
#  'Kossetsu Games',
#  'Logojogos',
#  'Homas Spelen',
#  'Five24 Labs',
#  'Phalanx Games Polska',
#  'Wooden Games Crokinole',
#  'Fruhling-Honpo',
#  'Cube Factory of Ideas',
#  'Flatout Games',
#  'Nova Era (Нова Ера)',
#  'Yemaia',
#  'Banana Games',
#  'Crómola',
#  'IGAMES',
#  'H. Baron',
#  'Marigó',
#  'Snowdale Design',
#  'Selecta Spel en Hobby',
#  'Hasbro',
#  'Abysse Corp.',
#  'Epoch Playthings',
#  'Outland',
#  'Spilbræt.dk',
#  'Barnes & Noble',
#  'Magpie (Korean Co)',
#  'Bandai',
#  'Capcom Co., Ltd.',
#  'MeepleBR',
#  'Igrology',
#  'Udo Grebe Gamedesign',
#  'Jelly Jelly Games',
#  'Geronimo Games',
#  'Precisamente',
#  'Albi',
#  'Stronghold Games',
#  'Cool Mini Or Not',
#  'hobbity.eu',
#  'F.X. Schmid',
#  'Kayenta Games',
#  'Target Games',
#  'Sugorokuya',
#  'ADC Blackfire Entertainment',
#  'Neptuno Games',
#  'Dice High Company',
#  'Wargames Club Publishing',
#  'Restoration Games',
#  'Fantasy Flight Games',
#  'Melmac Games',
#  'Le Grand Massif',
#  'Quined Games',
#  'Rosiness',
#  'danspil',
#  "Don't Panic Games",
#  'Winning Moves France',
#  'Pensamento Coletivo',
#  'Hachette Boardgames',
#  'Giochi Uniti',
#  'Les 12 Singes',
#  'Tezuka Productions',
#  'Gigante Jogos',
#  'NSKN Games',
#  'Fractal Juegos',
#  'Spółdzielnia Rzemieślnicza Wielobranżowa "Przemysław"',
#  'Osprey Games',
#  'Michael Stanfield',
#  'Dice Realm',
#  'Industries Prince, Inc.',
#  'Educa Borras',
#  'Piece Craft',
#  'OKAZU Brand',
#  'PieceKeeper Games',
#  'Japan Publications, Inc.',
#  'Rebel Studio',
#  'Tesco',
#  'ABRA',
#  'ABBA Games',
#  'The Purple Cow',
#  'Classic Games',
#  'Tempo Games (I)',
#  'Kronos Games (Krogam)',
#  'Cryptic Cardboard',
#  'Tasty Minstrel Games',
#  'Ігромаг',
#  'Crisloid',
#  'The United States Playing Card Company',
#  'Good Games Publishing',
#  'Grimpeur',
#  'MacGregor Historic Games',
#  'StrataMax Games',
#  'GAMEARChive',
#  'Chess Geeks',
#  'KR',
#  'Cocktail Games',
#  'Catch Up Games',
#  'alea',
#  'Jumping Turtle Games',
#  'Ben Sanders Co.',
#  'conception',
#  'K.E. Mathiasen A/S',
#  'Deep Thought Games, LLC',
#  'Paizo Publishing',
#  'Reveal Entertainment, Inc.',
#  'Sunriver Games',
#  'Atlantic Playing Card Company',
#  'Editrice Giochi',
#  'Compaya.hu: Gamer Café Kft.',
#  'Gammon Games',
#  'Playgo Ltd (Hong Kong)',
#  'Origames',
#  'Moria Games',
#  'Stupor Mundi',
#  'Do it games',
#  'Fullcap Games',
#  'Catalyst Game Labs',
#  'IntelliGames.BG',
#  'MB Juegos',
#  'Mandoo Games',
#  'GateOnGames',
#  'Casper',
#  'Wehrlegig Games',
#  'Schweppes',
#  'McNaughty Games',
#  'Diseños Orbitales',
#  'Kolossal Games',
#  'Hoyle Products',
#  'Salta da Caixa',
#  'Matagot',
#  'Board Game Circus',
#  'Baldar',
#  'Allied Van Lines',
#  'Magnetic Poetry Inc',
#  'Game Factory',
#  'Kilogames',
#  'Morning Players',
#  'リゴレ (rigoler)',
#  'IDW Games',
#  'Hurrican',
#  'Indie Boards & Cards',
#  'Mysterious Island Games',
#  'JOYPIE',
#  'Grail Games',
#  'Funforge',
#  "Lash's Bitters",
#  'Play Factory',
#  'Hobby',
#  'Multi-Man Publishing',
#  'SYU Creation',
#  'Purple Brain Creations',
#  'MB spel',
#  'MB Jeux',
#  'Game On Publishing LTD',
#  'Baborka Games',
#  'TGG Games',
#  'Rong Fa',
#  'JD Éditions',
#  'Black Monk',
#  'GoKids 玩樂小子',
#  'Crazy Pawn Games',
#  'Treetato Studio',
#  'Spielworxx',
#  'Griggling Games, Inc.',
#  'MINDOK',
#  'Arrakis Games',
#  '(Public Domain)',
#  'HUCH!',
#  'Ceilikan Jogos',
#  ...}

# %% [markdown]
# ### Creating Function to Filter Data Frames
# In this section I will create the function to filter the data frame to give the recommendations. I am going to retroactively drop any columns I do not use to limit the data frame and save on resources.

# %%
recom.drop(columns=['max_play_time', 'mechanics', ], inplace=True)

# %%
def category_filter(yr=None, play=None, ptime = None,
                    age=None, comp=None, cat=[],
                    des=[], pubs=[], rate=None):
    res = recom

        # Filter by categories
    if len(cat) != 0:
        for c in cat:
            res[c] = [1 if c in i else 0 for i in res['categories']]
        if len(cat) == 1:
            res = res[(res[cat[0]] == 1)]
        elif len(cat) == 2:
            res = res[(res[cat[0]] == 1) | (res[cat[1]] == 1)]
        else:
            res = res[(res[cat[0]] == 1) | (res[cat[1]] == 1) | (res[cat[2]] == 1)]

    # Filter by number of players
    if play != None:
        res = res[(res['min_players'] <= play) & (res['max_players'] >= play)]

    # Filter by year
    if yr != None:
        res = res[res['game_yr_pub'] == yr]
    
    # Filter by average rating
    if rate != None:
        res = res[res['avg_rating'] >= rate]
    
    # Filter by complexity
    if comp != None:
        res = res[(res['complexity'] >= (comp - .5)) & (res['complexity'] <= (comp + .5))]
    
    # Filter by play time
    if ptime != None:
        if ptime == '0 - 15':
            res = res[res['min_play_time'] <= 15]
        elif ptime == '15 - 30':
            res = res[(res['min_play_time'] > 15) & (res['min_play_time'] <= 30)]
        elif ptime == '30 - 45':
            res = res[(res['min_play_time'] > 30) & (res['min_play_time'] <= 45)]
        elif ptime == '45 - 60':
            res = res[(res['min_play_time'] > 45) & (res['min_play_time'] <= 60)]
        else:
            res = res[res['min_play_time'] > 60]
    
    # Filter by age constraint
    if age != None:
        res = res[res['min_age'] <= age]
    
    # Filter by designers
    if len(des) != 0:
        for c in des:
            res[c] = [1 if c in i else 0 for i in res['designers']]
        if len(des) == 1:
            res = res[(res[des[0]] == 1)]
        elif len(des) == 2:
            res = res[(res[des[0]] == 1) | (res[des[1]] == 1)]
        else:
            res = res[(res[des[0]] == 1) | (res[des[1]] == 1) | (res[des[2]] == 1)]
    
    # Filter by publishers
    if len(pubs) != 0:
        for c in pubs:
            res[c] = [1 if c in i else 0 for i in res['publishers']]
        if len(pubs) == 1:
            res = res[(res[pubs[0]] == 1)]
        elif len(pubs) == 2:
            res = res[(res[pubs[0]] == 1) | (res[pubs[1]] == 1)]
        else:
            res = res[(res[pubs[0]] == 1) | (res[pubs[1]] == 1) | (res[pubs[2]] == 1)]
            
    return res

# %%
category_filter(yr=2017,
                play=4,
                ptime='15 - 30',
                age=14,
                rate=7.5,
                comp=2,
                cat=['Puzzle', 'Card Game'],
                des=['Michael Kiesling', 'Bruce Glassco'], 
                pubs=['Next Move Games'])
# Out:
#     game_id game_name  game_yr_pub  min_players  max_players  min_play_time  \
# 60   230802      Azul         2017            2            4             30
#
#     min_age  avg_rating  complexity                            categories  \
# 60        8     7.79172      1.7658  Abstract Strategy|Puzzle|Renaissance
#
#            designers                                         publishers  rank  \
# 60  Michael Kiesling  Next Move Games|Plan B Games|Asmodee|Broadway ...    61
#
#     Puzzle  Card Game  Michael Kiesling  Bruce Glassco  Next Move Games
# 60       1          0                 1              0                1

# %% [markdown]
# Saving final version of game details data frame to csv. I will be using this for the app and going forward in the next notebooks.

# %%
recom.to_csv('../data/games_final.csv', index=False)
